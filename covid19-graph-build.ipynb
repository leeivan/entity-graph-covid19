# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit
from functools import reduce
from pyspark.sql import DataFrame

# %%
spark = SparkSession.builder.getOrCreate()

# %%
dfs_sections = spark.read \
.format("jdbc") \
.option("url", "jdbc:sqlite:/nfs/workspaces/datasets/covid-19/articles.sqlite") \
.option("dbtable", "(SELECT * FROM sections)").load()
dfs_sections.show()
dfs_articles = spark.read \
.format("jdbc") \
.option("url", "jdbc:sqlite:/nfs/workspaces/datasets/covid-19/articles.sqlite") \
.option("query", "(SELECT * FROM articles)") \
.option("customSchema", "Published STRING, Entry STRING").load()
dfs_articles.show()
dfs_citations = spark.read \
.format("jdbc") \
.option("url", "jdbc:sqlite:/nfs/workspaces/datasets/covid-19/articles.sqlite") \
.option("query", "(SELECT * FROM citations)").load()
dfs_citations.show()
# Out:
# +---+--------+--------+------+-----+--------------------+-----------+
# | Id| Article|    Tags|Design| Name|                Text|     Labels|
# +---+--------+--------+------+-----+--------------------+-----------+
# |  0|wvx6q999|COVID-19|     0|TITLE|Note from the edi...|   FRAGMENT|
# |  1|wvx6q999|COVID-19|     0| null|The situation has...|       null|
# |  2|wvx6q999|COVID-19|     0| null|Meanwhile, on 7 J...|       null|
# |  3|wvx6q999|COVID-19|     0| null|In order to suppo...|       null|
# |  4|wvx6q999|COVID-19|     0| null|For example, ther...|   FRAGMENT|
# |  5|wvx6q999|COVID-19|     0| null|In this issue of ...|   FRAGMENT|
# |  6|wvx6q999|COVID-19|     0| null|One is a research...|   FRAGMENT|
# |  7|wvx6q999|COVID-19|     0| null|on the developmen...|       null|
# |  8|wvx6q999|COVID-19|     0| null|Before this publi...|       null|
# |  9|wvx6q999|COVID-19|     0| null|The other is a ra...|       null|
# | 10|wvx6q999|COVID-19|     0| null|It also points ou...|   FRAGMENT|
# | 11|wvx6q999|COVID-19|     0| null|Today, the WHO Di...|   FRAGMENT|
# | 12|wvx6q999|COVID-19|     0| null|International hea...|       null|
# | 13|wvx6q999|COVID-19|     0| null|ECDC has set up a...|       null|
# | 14|wvx6q999|COVID-19|     0| null|At the end of 201...|       null|
# | 15|wvx6q999|COVID-19|     0| null|Just a day earlie...|       null|
# | 16|wvx6q999|COVID-19|     0| null|The post indicate...|SAMPLE_SIZE|
# | 17|wvx6q999|COVID-19|     0| null|In their accompan...|       null|
# | 18|wvx6q999|COVID-19|     0| null|severe acute resp...|   FRAGMENT|
# | 19|wvx6q999|COVID-19|     0| null|In order to suppo...|       null|
# +---+--------+--------+------+-----+--------------------+-----------+
# only showing top 20 rows
#
# +--------+------+-------------------+--------------------+--------------------+--------------------+--------+------+----+--------------------+--------------------+--------------------+----------+
# |      Id|Source|          Published|         Publication|             Authors|               Title|    Tags|Design|Size|              Sample|              Method|           Reference|     Entry|
# +--------+------+-------------------+--------------------+--------------------+--------------------+--------+------+----+--------------------+--------------------+--------------------+----------+
# |wvx6q999|   PMC|2020-01-23 00:00:00|       Euro Surveill|                null|Note from the edi...|COVID-19|     0|  20|The post indicate...|                null|https://www.ncbi....|2020-03-27|
# |64q3qcjy|   PMC|2020-02-27 00:00:00|       Euro Surveill|                null|Latest assessment...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-03-27|
# |bd7whqxf|   PMC|2020-03-05 00:00:00|       Euro Surveill|                null|Updated rapid ris...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-03-27|
# |l3ijkmwy|   PMC|2020-03-12 00:00:00|       Euro Surveill|                null|Updated rapid ris...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-03-27|
# |54glvasa|   PMC|2020-03-12 00:00:00|Med Klin Intensiv...|Kluge, Stefan; Ja...|Empfehlungen zur ...|COVID-19|     0|null|Grundsätzlich emp...|                null|https://www.ncbi....|2020-05-19|
# |t4ro1rl9|   PMC|2020-03-18 00:00:00|  Intensive Care Med|Corradi, F.; Via,...|Lung ultrasound a...|COVID-19|     0|null|The potential adv...|Semiquantitative ...|https://www.ncbi....|2020-05-19|
# |88hibsk5|   PMC|2020-03-23 00:00:00|Bone Marrow Trans...|Szer, Jeff; Weisd...|The impact of COV...|COVID-19|     0|null|The database cont...|The database cont...|https://www.ncbi....|2020-05-19|
# |8k34ed1o|   PMC|2020-03-30 00:00:00|    MMW Fortschr Med|                null|Fortbildung in Ze...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-04-03|
# |7s2i3sbj|   PMC|2020-03-30 00:00:00|    MMW Fortschr Med|                null|Schon junge Ärzte...|COVID-19|     0|null|COVID-19 spielte ...|COVID-19 spielte ...|https://www.ncbi....|2020-04-03|
# |1ob719sh|   PMC|2020-03-27 00:00:00|           Br Dent J|      Sellars, Shaun|   Interesting times|COVID-19|     0|null|Costs for alterna...|As 2020 enters fu...|https://www.ncbi....|2020-04-03|
# |cgcuzxdt|   PMC|2020-03-04 00:00:00|               Orbis| Shattuck, Thomas J.|The Race to Zero?...|COVID-19|     0|   2|The two men had p...|Between her elect...|https://www.ncbi....|2020-05-12|
# |apcueljv|   PMC|2020-03-19 00:00:00|   Lancet Psychiatry|Zhai, Yusen; Du, Xue|Mental health car...|COVID-19|     0|null|Coronavirus disea...|Coronavirus disea...|https://www.ncbi....|2020-06-04|
# |13pj0wmb|   PMC|2020-03-20 00:00:00|Lancet Public Health|Armitage, Richard...|COVID-19 and the ...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-03-27|
# |umz2v0ka|   PMC|2020-03-30 00:00:00|       Health Expect|      Aslani, Parisa|What are our heal...|COVID-19|     0|null|For weeks, we wer...|For weeks, we wer...|https://www.ncbi....|2020-04-10|
# |wuuhlowd|   PMC|2020-04-01 00:00:00|          Inter Econ|     Valkonen, Tarmo|The Finnish Pensi...|COVID-19|     9|null|Several new early...|Private sector pe...|https://www.ncbi....|2020-05-19|
# |1mchg5yg|   PMC|2020-03-09 00:00:00|                null|Zhao, Shi; Cao, P...|COVID-19 and gend...|COVID-19|     0|   8|1 The mechanism b...|We examined the p...|https://www.ncbi....|2020-04-10|
# |6dwpkjaj|   PMC|2020-03-26 00:00:00|       Euro Surveill|                null|Updated rapid ris...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-04-10|
# |qwc0inzi|   PMC|2020-03-11 00:00:00|       J Nurse Pract| Neal-Boylan, Leslie|Are We Ready for ...|COVID-19|     0|   4|I quickly moved m...|                null|https://www.ncbi....|2020-05-19|
# |cmqtarm0|   PMC|2020-03-30 00:00:00|        Lancet Oncol| The Lancet Oncology|COVID-19: global ...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-04-03|
# |vahd59z8|   PMC|2020-04-01 00:00:00|  J Am Med Dir Assoc|Cesari, Matteo; P...|COVID-19 in Italy...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-05-19|
# +--------+------+-------------------+--------------------+--------------------+--------------------+--------+------+----+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows
#
# +--------------------+--------+
# |               Title|Mentions|
# +--------------------+--------+
# |                null|   25717|
# |Detection of 2019...|     878|
# |Real-time tentati...|       6|
# |Risk assessment: ...|       4|
# |European Centre f...|      37|
# |Real-time tentati...|      82|
# |Novel 2019 corona...|       5|
# |Undiagnosed pneum...|       1|
# |Laboratory testin...|      18|
# |Detection of 2019...|      43|
# |Covid-19 drug int...|       4|
# |Clinicalcourseand...|       5|
# |Clinical features...|    3607|
# |AWMF (2020) S3-Le...|       1|
# |Exhaled air dispe...|      57|
# |Novel coronavirus...|       5|
# |Staff safety duri...|      95|
# |AWMF (2017) S3-Le...|       2|
# |Novel coronavirus...|      12|
# |COVID-19: a novel...|      35|
# +--------------------+--------+
# only showing top 20 rows

# %%
ner_type = ["BC2GM","BC4CHEMD","BC5CDR-chem","BC5CDR-disease","JNLPBA","NCBI-disease","linnaeus","s800"]
ner_app = []
for item in ner_type :
    ner_path = "/home/leeivan/bio_corpus/ner/"+ item  + "/all_entity.csv"
    df = spark.read.format("csv").option("header","true").load(ner_path)
    df = df.withColumn("type", lit(item))
    ner_app.append(df)
df_ner_all = reduce(DataFrame.unionAll, ner_app)
df_ner_all = df_ner_all.withColumnRenamed("type", "ner_type")
df_ner_all.show()
# Out:
# +--------------------+---+----------+--------+
# |              entity|  n|section_id|ner_type|
# +--------------------+---+----------+--------+
# |                AAK1|  1|      1522|   BC2GM|
# |      Januase Kinase|  1|      1523|   BC2GM|
# |              IL - 8|  1|      3461|   BC2GM|
# |              IL - 8|  2|      3461|   BC2GM|
# |              IL - 8|  3|      3461|   BC2GM|
# |                b A1|  1|      6798|   BC2GM|
# |                BafA|  2|      6798|   BC2GM|
# |                BafA|  1|      6799|   BC2GM|
# |vacuolar type H (...|  2|      6799|   BC2GM|
# |          v - ATPase|  3|      6799|   BC2GM|
# |                   C|  1|      6800|   BC2GM|
# |                BafA|  2|      6800|   BC2GM|
# |mammalian target ...|  3|      6800|   BC2GM|
# |              mTORC1|  4|      6800|   BC2GM|
# |              mTORC1|  1|      6801|   BC2GM|
# |              mTORC1|  2|      6801|   BC2GM|
# |              mTORC1|  1|      6803|   BC2GM|
# |transcription fac...|  1|      6804|   BC2GM|
# |                TFEB|  2|      6804|   BC2GM|
# |              mTORC1|  3|      6804|   BC2GM|
# +--------------------+---+----------+--------+
# only showing top 20 rows

# %%
re_type = ["GAD","euadr"]
re_app = []
for item in re_type:
    re_path = "/home/leeivan/bio_corpus/re_all_in_one/" + item + "/all_relations.csv"
    df = spark.read.format("csv").option("header","true").load(re_path)
    df = df.withColumn("type", lit(item))
    re_app.append(df)

# %%
df_re_all = reduce(DataFrame.unionAll, re_app)
df_re_all = df_re_all.withColumnRenamed("type", "re_type")
df_re_all.show()
# Out:
# +----------+-------+
# |section_id|re_type|
# +----------+-------+
# |       222|    GAD|
# |      2780|    GAD|
# |      4270|    GAD|
# |      8822|    GAD|
# |      9142|    GAD|
# |      9614|    GAD|
# |      9998|    GAD|
# |     10000|    GAD|
# |     11154|    GAD|
# |     12708|    GAD|
# |     12709|    GAD|
# |     12710|    GAD|
# |     13385|    GAD|
# |     14966|    GAD|
# |     15913|    GAD|
# |     15918|    GAD|
# |     17060|    GAD|
# |     18664|    GAD|
# |     18665|    GAD|
# |     20429|    GAD|
# +----------+-------+
# only showing top 20 rows

# %%
df_ner_re = df_ner_all.join(df_re_all, "section_id")
df_ner_re.show()
df_ner_re_src = df_ner_re.withColumnRenamed("entity","entity_src") \
.withColumnRenamed("n", "n_src") \
.withColumnRenamed("ner_type", "ner_type_src") \
.withColumnRenamed("re_type", "re_type_src")
df_ner_re_src.show()
df_ner_re_dst = df_ner_re.withColumnRenamed("entity","entity_dst") \
.withColumnRenamed("n", "n_dst") \
.withColumnRenamed("ner_type", "ner_type_dst") \
.withColumnRenamed("re_type", "re_type_dst")
df_ner_re_dst.show()
df_ner_re_src_dst = df_ner_re_src.join(df_ner_re_dst, "section_id")
df_ner_re_src_dst.show()
df_ner_re_src_dst = df_ner_re_src_dst.filter("entity_src != entity_dst") \
.filter("re_type_src == re_type_dst") \
.filter("ner_type_src == ner_type_dst")
# Out:
# +----------+--------------------+---+--------+-------+
# |section_id|              entity|  n|ner_type|re_type|
# +----------+--------------------+---+--------+-------+
# |      1523|      Januase Kinase|  1|   BC2GM|  euadr|
# |      6799|                BafA|  1|   BC2GM|  euadr|
# |      6799|vacuolar type H (...|  2|   BC2GM|  euadr|
# |      6799|          v - ATPase|  3|   BC2GM|  euadr|
# |      6803|              mTORC1|  1|   BC2GM|  euadr|
# |      6805|                BafA|  1|   BC2GM|  euadr|
# |      6805|              mTORC1|  2|   BC2GM|  euadr|
# |     10479|                   h|  1|   BC2GM|  euadr|
# |     16293|   ribosome helicase|  1|   BC2GM|  euadr|
# |     18261|                  CR|  1|   BC2GM|  euadr|
# |     18261|              Cas13b|  2|   BC2GM|  euadr|
# |     18265|              Cas13b|  1|   BC2GM|  euadr|
# |     20120|      HLA - B27 mRNA|  1|   BC2GM|  euadr|
# |     20122|      HLA - B27 mRNA|  1|   BC2GM|  euadr|
# |     23056|               renin|  1|   BC2GM|  euadr|
# |     23056|         angiotensin|  2|   BC2GM|  euadr|
# |     23056|                  RA|  3|   BC2GM|  euadr|
# |     23058| Angiotensin peptide|  1|   BC2GM|  euadr|
# |     23059|               renin|  1|   BC2GM|  euadr|
# |     23059|         angiotensin|  2|   BC2GM|  euadr|
# +----------+--------------------+---+--------+-------+
# only showing top 20 rows
#
# +----------+--------------------+-----+------------+-----------+
# |section_id|          entity_src|n_src|ner_type_src|re_type_src|
# +----------+--------------------+-----+------------+-----------+
# |      1523|      Januase Kinase|    1|       BC2GM|      euadr|
# |      6799|                BafA|    1|       BC2GM|      euadr|
# |      6799|vacuolar type H (...|    2|       BC2GM|      euadr|
# |      6799|          v - ATPase|    3|       BC2GM|      euadr|
# |      6803|              mTORC1|    1|       BC2GM|      euadr|
# |      6805|                BafA|    1|       BC2GM|      euadr|
# |      6805|              mTORC1|    2|       BC2GM|      euadr|
# |     10479|                   h|    1|       BC2GM|      euadr|
# |     16293|   ribosome helicase|    1|       BC2GM|      euadr|
# |     18261|                  CR|    1|       BC2GM|      euadr|
# |     18261|              Cas13b|    2|       BC2GM|      euadr|
# |     18265|              Cas13b|    1|       BC2GM|      euadr|
# |     20120|      HLA - B27 mRNA|    1|       BC2GM|      euadr|
# |     20122|      HLA - B27 mRNA|    1|       BC2GM|      euadr|
# |     23056|               renin|    1|       BC2GM|      euadr|
# |     23056|         angiotensin|    2|       BC2GM|      euadr|
# |     23056|                  RA|    3|       BC2GM|      euadr|
# |     23058| Angiotensin peptide|    1|       BC2GM|      euadr|
# |     23059|               renin|    1|       BC2GM|      euadr|
# |     23059|         angiotensin|    2|       BC2GM|      euadr|
# +----------+--------------------+-----+------------+-----------+
# only showing top 20 rows
#
# +----------+--------------------+-----+------------+-----------+
# |section_id|          entity_dst|n_dst|ner_type_dst|re_type_dst|
# +----------+--------------------+-----+------------+-----------+
# |      1523|      Januase Kinase|    1|       BC2GM|      euadr|
# |      6799|                BafA|    1|       BC2GM|      euadr|
# |      6799|vacuolar type H (...|    2|       BC2GM|      euadr|
# |      6799|          v - ATPase|    3|       BC2GM|      euadr|
# |      6803|              mTORC1|    1|       BC2GM|      euadr|
# |      6805|                BafA|    1|       BC2GM|      euadr|
# |      6805|              mTORC1|    2|       BC2GM|      euadr|
# |     10479|                   h|    1|       BC2GM|      euadr|
# |     16293|   ribosome helicase|    1|       BC2GM|      euadr|
# |     18261|                  CR|    1|       BC2GM|      euadr|
# |     18261|              Cas13b|    2|       BC2GM|      euadr|
# |     18265|              Cas13b|    1|       BC2GM|      euadr|
# |     20120|      HLA - B27 mRNA|    1|       BC2GM|      euadr|
# |     20122|      HLA - B27 mRNA|    1|       BC2GM|      euadr|
# |     23056|               renin|    1|       BC2GM|      euadr|
# |     23056|         angiotensin|    2|       BC2GM|      euadr|
# |     23056|                  RA|    3|       BC2GM|      euadr|
# |     23058| Angiotensin peptide|    1|       BC2GM|      euadr|
# |     23059|               renin|    1|       BC2GM|      euadr|
# |     23059|         angiotensin|    2|       BC2GM|      euadr|
# +----------+--------------------+-----+------------+-----------+
# only showing top 20 rows
#
# +----------+----------+-----+------------+-----------+-----------+-----+--------------+-----------+
# |section_id|entity_src|n_src|ner_type_src|re_type_src| entity_dst|n_dst|  ner_type_dst|re_type_dst|
# +----------+----------+-----+------------+-----------+-----------+-----+--------------+-----------+
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr|         CO|    1|BC5CDR-disease|      euadr|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr|         CO|    1|BC5CDR-disease|        GAD|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr|respiratory|    2|BC5CDR-disease|      euadr|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr|respiratory|    2|BC5CDR-disease|        GAD|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr|         CO|    3|BC5CDR-disease|      euadr|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr|         CO|    3|BC5CDR-disease|        GAD|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr| COVID - 19|    1|          s800|      euadr|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr| COVID - 19|    1|          s800|        GAD|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr|   COD - 19|    2|          s800|      euadr|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr|   COD - 19|    2|          s800|        GAD|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr| COVID - 19|    1|  NCBI-disease|      euadr|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr| COVID - 19|    1|  NCBI-disease|        GAD|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr|respiratory|    2|  NCBI-disease|      euadr|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr|respiratory|    2|  NCBI-disease|        GAD|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr| COVID - 19|    3|  NCBI-disease|      euadr|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr| COVID - 19|    3|  NCBI-disease|        GAD|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr|    patient|    1|      linnaeus|      euadr|
# |   1000888|COVID - 19|    1|NCBI-disease|      euadr|    patient|    1|      linnaeus|        GAD|
# |   1000888|COVID - 19|    1|NCBI-disease|        GAD|         CO|    1|BC5CDR-disease|      euadr|
# |   1000888|COVID - 19|    1|NCBI-disease|        GAD|         CO|    1|BC5CDR-disease|        GAD|
# +----------+----------+-----+------------+-----------+-----------+-----+--------------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import *

# %%
e_drop_duplicate = df_ner_re_src_dst.withColumn("entity_pair",array_join(array_sort(array(col("entity_src"),col("entity_dst"))),"_")).dropDuplicates(["entity_pair"]).drop("entity_pair")

# %%
from pyspark.sql.window import Window as W
v = df_ner_all.groupBy("entity").agg(collect_set("section_id").alias("sections"))

# %%
v.cache()
# Out:
# DataFrame[entity: string, sections: array<string>]

# %%
v = v.withColumn("idx", monotonically_increasing_id())
windowSpec = W.orderBy("idx")
v = v.withColumn("id", row_number().over(windowSpec)).drop("idx")
v.show()
# Out:
# +--------------------+--------------------+---+
# |              entity|            sections| id|
# +--------------------+--------------------+---+
# |"Taxifolin 3 ' - ...|           [1278739]|  1|
# |$ \ beta $ - hairpin|           [1539578]|  2|
# |         ( E , E ) -|           [1503298]|  3|
# |- 19 and H1N1 swi...|  [5220609, 1411652]|  4|
# |              - Nrf2|           [6906166]|  5|
# |        - nCV N gene|           [3823453]|  6|
# |         - occlusion|   [1123441, 642104]|  7|
# |- related infections|   [1354288, 665292]|  8|
# |1 , 2 , 3 , 4 - t...|[1291599, 8620851...|  9|
# |1 , 3 , 6 - trihy...|           [1538143]| 10|
# |       1 microglobul|           [6290762]| 11|
# |                 13C|[874533, 1470080,...| 12|
# |     17β - estradiol|           [3906171]| 13|
# |     1ab polyprotein|[622787, 920614, ...| 14|
# |2 , 2 ' - Azino -...|            [853792]| 15|
# |2019 - nCoV main ...|[682594, 7808126,...| 16|
# |2019 Corona Virus...|[7274121, 1352238...| 17|
# |3 , 5 - Di - O - ...|  [1064612, 3040722]| 18|
# |3 - to - 5 exonuc...|           [5398839]| 19|
# |     3CL pro complex|  [5569142, 1583834]| 20|
# +--------------------+--------------------+---+
# only showing top 20 rows

# %%
v.filter("entity = 'COVID - 19'").show()
# Out:
# +----------+--------------------+-----+
# |    entity|            sections|   id|
# +----------+--------------------+-----+
# |COVID - 19|[6430795, 1018353...|45423|
# +----------+--------------------+-----+

# %%
e_drop_duplicate = e_drop_duplicate.select("entity_src","entity_dst","re_type_src")
# e = e.withColumnRenamed("entity_src", "src").withColumnRenamed("entity_dst", "dst") \
# .withColumnRenamed("re_type_src", "relationship")
e_drop_duplicate.show()
# Out:
# +--------------------+--------------------+-----------+
# |          entity_src|          entity_dst|re_type_src|
# +--------------------+--------------------+-----------+
# |sesquiterpen hydr...|( E ) - ß - farne...|      euadr|
# |                   ,|   Alloyohimbine , ,|      euadr|
# |                 3CL|           - ACE - 2|      euadr|
# |  palindrome repeats|               - Cas|      euadr|
# |             - LARP1|        5 ′ TOP mRNA|        GAD|
# |                coki|            / IL - 6|        GAD|
# |1 , 10 - phenanth...|[ Co ( indo - O ,...|      euadr|
# |                 111|               human|      euadr|
# |14 - 3 - 3 protei...|               YWHAE|      euadr|
# |       spike protein|2 - O - ribose me...|        GAD|
# |                trip|             2 ′ - C|      euadr|
# |         2019 - nCoV|      angiotensin II|      euadr|
# |receptor binding ...|        2019 - spike|      euadr|
# |      SARS - CoV - 2|            2019 nCO|      euadr|
# |             24 , 25|                   e|      euadr|
# |             Aularin|3 , 5 - Di - O - ...|      euadr|
# |                ACE2|          3CLpro ‐ 1|      euadr|
# |      5p - replicase|           orf1 / ab|      euadr|
# |7 Pangolin - Cov ...|                ORFs|      euadr|
# |        stem - loops|       A - site tRNA|      euadr|
# +--------------------+--------------------+-----------+
# only showing top 20 rows

# %%
e_drop_duplicate = e_drop_duplicate.join(v, e_drop_duplicate.entity_src == v.entity).select("id","entity_dst","re_type_src").withColumnRenamed("id","src")
e = e_drop_duplicate.join(v, e_drop_duplicate.entity_dst == v.entity).select("id","src","re_type_src").withColumnRenamed("id","dst").withColumnRenamed("re_type_src","relationship")

# %%
e.cache()
# Out:
# DataFrame[dst: int, src: int, relationship: string]

# %%
e.show()
# Out:
# +---+-----+------------+
# |dst|  src|relationship|
# +---+-----+------------+
# |  1|50272|       euadr|
# |  1|34433|       euadr|
# |  1|26113|       euadr|
# |  1|77094|       euadr|
# |  5|53014|       euadr|
# |  9|18661|         GAD|
# | 10|50656|       euadr|
# | 13|95216|       euadr|
# | 13|28406|       euadr|
# | 18|48101|       euadr|
# | 18| 4370|       euadr|
# | 18|26521|       euadr|
# | 18|93377|       euadr|
# | 19|17642|         GAD|
# | 19|93139|       euadr|
# | 19|33829|       euadr|
# | 19|47794|         GAD|
# | 19|91314|       euadr|
# | 19|32219|       euadr|
# | 19|70152|       euadr|
# +---+-----+------------+
# only showing top 20 rows

# %%
from graphframes import *
g = GraphFrame(v,e)

# %%
gad_g = g.filterVertices("entity like '%respiratory%' or entity like '%COVID%'").dropIsolatedVertices()

# %%
gad_g = g.filterEdges("src = 45423 or dst = 45423").dropIsolatedVertices()

# %%
gad_g.vertices.show()
# Out:
# +---+--------------------+--------------------+
# | id|              entity|            sections|
# +---+--------------------+--------------------+
# | 59| COVID - 19 distress|[1439412, 1494838...|
# | 64|          COVID - op|            [858177]|
# | 71|                 CRS|[1186406, 4756921...|
# | 72|    CV complications|[935312, 1110874,...|
# |114|                 GIS|  [1330911, 6925845]|
# |140|                   K|[5196416, 5474943...|
# |146|  Kidney dysfunction|[7868742, 4174959...|
# |148|                  LT|[1183680, 1613277...|
# |151|    MERS coronavirus|[657579, 1436661,...|
# |154|                  MM|[8291247, 843908,...|
# |168|               NMOSD|[1259429, 1490185...|
# |218| SARS - CoV - 2 - on|[2503539, 2795172...|
# |226|   SARS - CoV2 virus|[2392326, 1063890...|
# |227|SARS - associated...|           [1754433]|
# |239|Severe acute resp...|    [877046, 618577]|
# |250|US covirus diseas...|            [947468]|
# |279|            arrhymia|[1092038, 639157,...|
# |287|      bronchiectasis|[2115523, 2127833...|
# |300|chronic lower res...|[6696663, 725634,...|
# |303|          co of 2019|           [1606868]|
# +---+--------------------+--------------------+
# only showing top 20 rows

# %%
gad_g.edges.count()
# Out:
# 5682

# %%
gad_g_v = gad_g.vertices.select("id").rdd.flatMap(lambda x: x).collect()

# %%
nodes = [{'name': i["entity"], 'size': i["size"]}
         for i in gad_g.vertices.select("entity", size("sections").alias("size")).collect()]

# %%
links = [{'source': gad_g_v.index(u["source"]), 'target': gad_g_v.index(u["target"])}
         for u in gad_g.edges.withColumnRenamed("dst","target").withColumnRenamed("src","source").select("source","target","relationship").collect()]

# %%
graph = {'nodes': nodes, "links": links}

# %%
graph
# Out:
# {'nodes': [{'name': 'COVID - 19 distress', 'size': 8},
#   {'name': 'COVID - op', 'size': 1},
#   {'name': 'CRS', 'size': 252},
#   {'name': 'CV complications', 'size': 6},
#   {'name': 'GIS', 'size': 2},
#   {'name': 'K', 'size': 227},
#   {'name': 'Kidney dysfunction', 'size': 3},
#   {'name': 'LT', 'size': 14},
#   {'name': 'MERS coronavirus', 'size': 20},
#   {'name': 'MM', 'size': 59},
#   {'name': 'NMOSD', 'size': 66},
#   {'name': 'SARS - CoV - 2 - on', 'size': 3},
#   {'name': 'SARS - CoV2 virus', 'size': 67},
#   {'name': 'SARS - associated coronavirus 2', 'size': 1},
#   {'name': 'Severe acute respiratory syndrome coronavirus 2 related',
#    'size': 2},
#   {'name': 'US covirus disease 2019', 'size': 1},
#   {'name': 'arrhymia', 'size': 4},
#   {'name': 'bronchiectasis', 'size': 86},
#   {'name': 'chronic lower respiratory disease', 'size': 5},
#   {'name': 'co of 2019', 'size': 1},
#   {'name': 'covir', 'size': 13},
#   {'name': 'hemolytic uremic syndrome', 'size': 2},
#   {'name': 'inflammatory', 'size': 262},
#   {'name': 'inflammatory immune diseases', 'size': 2},
#   {'name': 'intrauterine growth restriction', 'size': 6},
#   {'name': 'ischemic strokesVID - 19', 'size': 1},
#   {'name': 'new coronavirus', 'size': 2},
#   {'name': 'obsessive - compulsive symptoms', 'size': 23},
#   {'name': 'olfactory dysfunction', 'size': 189},
#   {'name': 'physical , cognitive and / or mental health impairments',
#    'size': 1},
#   {'name': 'postmonism', 'size': 2},
#   {'name': 'psychological problems', 'size': 59},
#   {'name': 'ronavirus', 'size': 21},
#   {'name': 'severe COVID - 19', 'size': 12},
#   {'name': 'severe acute respiratory syndrome 2 virus', 'size': 4},
#   {'name': 'severe lung disease', 'size': 8},
#   {'name': 'sudden death', 'size': 53},
#   {'name': '1711 rinderpest', 'size': 2},
#   {'name': 'Alt', 'size': 11},
#   {'name': 'COVID - 19D - 19', 'size': 37},
#   {'name': 'COVID - 19VI - 19', 'size': 6},
#   {'name': 'Corona', 'size': 67},
#   {'name': 'Dys', 'size': 27},
#   {'name': 'LV dysfunction', 'size': 5},
#   {'name': 'Lymphopenia', 'size': 132},
#   {'name': 'NCD', 'size': 65},
#   {'name': 'Otitis extern', 'size': 1},
#   {'name': 'SARS - Co - V2', 'size': 3},
#   {'name': 'acute renal injury', 'size': 19},
#   {'name': 'acute surgical condition', 'size': 2},
#   {'name': 'chronic B cell lymphocytic leukemia', 'size': 2},
#   {'name': 'co viral', 'size': 3},
#   {'name': 'covid - 19 pneumonia', 'size': 7},
#   {'name': 'disasters diseases', 'size': 2},
#   {'name': 'heart , liver , kidney problems', 'size': 2},
#   {'name': 'interstitial lung disease', 'size': 57},
#   {'name': 'liver complications', 'size': 1},
#   {'name': 'loss of taste and smell', 'size': 25},
#   {'name': 'malignant ventricular arrhythmia', 'size': 6},
#   {'name': 'multiorgan impairment', 'size': 2},
#   {'name': 'nausea', 'size': 386},
#   {'name': 'premic psychiatric disorder', 'size': 1},
#   {'name': 'severe urticarial attack', 'size': 2},
#   {'name': 'sight - threatening diseases', 'size': 3},
#   {'name': 'virus disease', 'size': 191},
#   {'name': 'B . 6', 'size': 9},
#   {'name': 'Covirus disease – 2019', 'size': 1},
#   {'name': 'FND', 'size': 4},
#   {'name': 'Influenza virus', 'size': 21},
#   {'name': 'LVA', 'size': 3},
#   {'name': 'abnormalities in coagulation', 'size': 2},
#   {'name': 'acute respiratory problems', 'size': 2},
#   {'name': 'bacterial and viral pneumonia', 'size': 8},
#   {'name': 'black swan', 'size': 13},
#   {'name': 'cardiac arrests', 'size': 33},
#   {'name': 'child maltreatment', 'size': 30},
#   {'name': 'der', 'size': 65},
#   {'name': 'deterior', 'size': 2},
#   {'name': 'disseminated coagulation', 'size': 2},
#   {'name': 'lower extremity arterial thrombosis', 'size': 4},
#   {'name': 'multi - organ failures', 'size': 6},
#   {'name': 'posttra stress', 'size': 13},
#   {'name': 'pumococcus', 'size': 1},
#   {'name': 'respiratory dyspnea', 'size': 2},
#   {'name': 'status epilepticus', 'size': 45},
#   {'name': 'thbotic complications', 'size': 138},
#   {'name': 'tissue inflammation', 'size': 4},
#   {'name': 'vaslitis', 'size': 9},
#   {'name': '- op', 'size': 4},
#   {'name': '2019 - covirus', 'size': 2},
#   {'name': '2019 coronavirus disease pan', 'size': 4},
#   {'name': 'CO - Lung', 'size': 1},
#   {'name': 'Charcot - Marie - Tooth disease', 'size': 2},
#   {'name': 'MIS', 'size': 70},
#   {'name': 'P consolidation', 'size': 2},
#   {'name': 'SARS - COV - 2virus - 2019', 'size': 1},
#   {'name': 'SARS - CoVID -', 'size': 1},
#   {'name': 'Severe Acute Retory Syndrome coronavirus 2', 'size': 27},
#   {'name': 'acute coronary syndrome', 'size': 182},
#   {'name': 'acute nephropathy', 'size': 1},
#   {'name': 'acute viral pneumonitis', 'size': 2},
#   {'name': 'anorexia', 'size': 161},
#   {'name': 'cancer Cancer', 'size': 4},
#   {'name': 'co th', 'size': 1},
#   {'name': 'covirus del 2019', 'size': 1},
#   {'name': 'cyste', 'size': 4},
#   {'name': 'diseases of ophthalmology', 'size': 1},
#   {'name': 'giant bulla', 'size': 4},
#   {'name': 'imp of liver function', 'size': 2},
#   {'name': 'infectious illness', 'size': 11},
#   {'name': 'neseny dysfunction', 'size': 2},
#   {'name': 'opacities', 'size': 7},
#   {'name': 'opht', 'size': 2},
#   {'name': 'pneumonia diseases', 'size': 12},
#   {'name': 'productive cough', 'size': 24},
#   {'name': 'sinonasal symptoms', 'size': 13},
#   {'name': 'suicide', 'size': 389},
#   {'name': 'systemic lupus erythematous', 'size': 5},
#   {'name': 'COVID - 19 A', 'size': 3},
#   {'name': 'Chi', 'size': 21},
#   {'name': 'DIC - syndrome', 'size': 1},
#   {'name': 'FI', 'size': 14},
#   {'name': 'ISDs', 'size': 4},
#   {'name': 'Nological complications', 'size': 2},
#   {'name': 'SC', 'size': 71},
#   {'name': 'Venezuelan equine encephalitis virus', 'size': 2},
#   {'name': 'anti - SARS - CoV - 2 antibodies', 'size': 115},
#   {'name': 'anxiety ,', 'size': 26},
#   {'name': 'cardiac diseases', 'size': 13},
#   {'name': 'dental diseases', 'size': 2},
#   {'name': 'falls', 'size': 49},
#   {'name': 'gastrointestinal symptoms', 'size': 421},
#   {'name': 'herpes zoster', 'size': 22},
#   {'name': 'immune mediated disease peripheral nerves and nerve roots',
#    'size': 1},
#   {'name': 'impair of liver function', 'size': 2},
#   {'name': 'maintenance HD', 'size': 2},
#   {'name': 'muscle aches', 'size': 20},
#   {'name': 'nCOV19', 'size': 2},
#   {'name': 'nursing home', 'size': 3},
#   {'name': 'pancreatic cancer', 'size': 17},
#   {'name': 'pneumonia - associated respiratory syndrome', 'size': 9},
#   {'name': 'pu', 'size': 29},
#   {'name': 'thbot', 'size': 275},
#   {'name': 'trauma', 'size': 924},
#   {'name': 'vascular dys', 'size': 2},
#   {'name': 'CD15', 'size': 1},
#   {'name': 'CODI - 19', 'size': 1},
#   {'name': 'Caries', 'size': 6},
#   {'name': 'Cyine release syndrome', 'size': 6},
#   {'name': 'EA', 'size': 32},
#   {'name': 'MERS ) - CoV 2019', 'size': 1},
#   {'name': 'Middle syndrome', 'size': 13},
#   {'name': 'SARS - COV 2', 'size': 45},
#   {'name': 'Wuhan Novel Coronavirus disease', 'size': 1},
#   {'name': 'acute respiratory tract infections', 'size': 14},
#   {'name': 'advanced cancer', 'size': 23},
#   {'name': 'canine enteric coronavirus', 'size': 2},
#   {'name': 'chickens', 'size': 41},
#   {'name': 'co virus disease 2019', 'size': 5},
#   {'name': 'community acquired coronavirus disease 2019', 'size': 4},
#   {'name': 'complement - driven diseases', 'size': 2},
#   {'name': 'coronavirus - 2', 'size': 57},
#   {'name': 'coronavirus 19', 'size': 9},
#   {'name': 'covirus - related diseases', 'size': 5},
#   {'name': 'covirus 2', 'size': 148},
#   {'name': 'covirus disease', 'size': 367},
#   {'name': 'direct or indirect vasculopathy', 'size': 2},
#   {'name': 'headache disorders', 'size': 9},
#   {'name': 'invasive S . pneumoniae disease', 'size': 2},
#   {'name': 'joint stiffness', 'size': 5},
#   {'name': 'killer cell immunoglobulin like receptor genes', 'size': 2},
#   {'name': 'lymphatic abnormalities', 'size': 2},
#   {'name': 'metastatic breast cancer', 'size': 12},
#   {'name': 'mic covirus', 'size': 3},
#   {'name': 'neurological', 'size': 150},
#   {'name': 'olfactory dysfunctions', 'size': 8},
#   {'name': 'oropharyngeal dysphagia', 'size': 4},
#   {'name': 'pandemic viral illness', 'size': 2},
#   {'name': 'pernio', 'size': 20},
#   {'name': 'pulmonary abnormal', 'size': 7},
#   {'name': 'pulmonary circulation dysfunction', 'size': 1},
#   {'name': 'respiratory virus infectionVID', 'size': 1},
#   {'name': 'rona virus', 'size': 13},
#   {'name': 'severe acute respiratory syndrome coronavirus2', 'size': 4},
#   {'name': 'soybean', 'size': 4},
#   {'name': 'splenic infarction', 'size': 4},
#   {'name': 'thrombotic events', 'size': 21},
#   {'name': 'vertebral artery thrombosis', 'size': 2},
#   {'name': 'viral replicase', 'size': 7},
#   {'name': '25 - hydroxy vitamin D deficiency', 'size': 2},
#   {'name': 'CO 19', 'size': 8579},
#   {'name': 'COVID - 19 infections', 'size': 584},
#   {'name': 'CVDs', 'size': 15},
#   {'name': 'Coronavirus COVID - 19', 'size': 10},
#   {'name': 'Covirus Disease - 19', 'size': 43},
#   {'name': 'Cranial nerve symptoms', 'size': 2},
#   {'name': 'EVD', 'size': 73},
#   {'name': 'GH - IGF1 axis impairment', 'size': 1},
#   {'name': 'ODs', 'size': 17},
#   {'name': 'Posttraumatic stress disorder', 'size': 2},
#   {'name': 'SARS - CoV - 2 disease 2019', 'size': 27},
#   {'name': 'SARS - Cov 2', 'size': 30},
#   {'name': 'acute co', 'size': 4},
#   {'name': 'anmia', 'size': 81},
#   {'name': 'anosmia of', 'size': 4},
#   {'name': 'arboviral diseases', 'size': 5},
#   {'name': 'auto - immunity', 'size': 1},
#   {'name': 'di lung involvement', 'size': 2},
#   {'name': 'high - altitude pulmonary edema', 'size': 1},
#   {'name': 'immune storm', 'size': 2},
#   {'name': 'l', 'size': 137},
#   {'name': 'measles virus', 'size': 26},
#   {'name': 'moral injury', 'size': 19},
#   {'name': 'nelogical manifest', 'size': 2},
#   {'name': 'novel Coronavirus Disease', 'size': 7},
#   {'name': 'oropharyngeal gonorrhea', 'size': 1},
#   {'name': 'pancreatic disease', 'size': 2},
#   {'name': 'para', 'size': 38},
#   {'name': 'puonic', 'size': 2},
#   {'name': 'ravages', 'size': 2},
#   {'name': 'respiratory conditions', 'size': 31},
#   {'name': 'schizophrenia - spectrum disorders', 'size': 6},
#   {'name': 'severe acute respiratory syndrome covirus', 'size': 103},
#   {'name': 'severe and critical COVID - 19', 'size': 2},
#   {'name': 'tachycardia', 'size': 65},
#   {'name': 'Hypovolemic hyponatremia', 'size': 2},
#   {'name': 'MDD', 'size': 29},
#   {'name': 'Overweight or obesity', 'size': 1},
#   {'name': 'SARS - CoV - 2 ) pneumonia', 'size': 20},
#   {'name': 'SARS - CoV - 2 strand RNA viral respiratory disease', 'size': 2},
#   {'name': 'SOS', 'size': 2},
#   {'name': 'Severe Acute Respiratory Syndrome Corona', 'size': 24},
#   {'name': 'Severe Acute Retory Sdrome - Coronavirus - 2', 'size': 6},
#   {'name': 'Severe acute respiratory syndrome coronavirus 2ronavirus disease of 2019',
#    'size': 1},
#   {'name': 'Thrombotic disease', 'size': 2},
#   {'name': 'bronchopneumonia', 'size': 41},
#   {'name': 'carbon dioxide naosis postint tracheal stenosis', 'size': 2},
#   {'name': 'cardio - renal - pulmonary damage', 'size': 2},
#   {'name': 'cardiovascular manifest', 'size': 1},
#   {'name': 'comnicable disease', 'size': 18},
#   {'name': 'diabe', 'size': 149},
#   {'name': 'diff cardiac depression', 'size': 3},
#   {'name': 'disorders', 'size': 29},
#   {'name': 'emotional and physical fatigue', 'size': 1},
#   {'name': 'endocrine conditions', 'size': 4},
#   {'name': 'fatigue or', 'size': 1},
#   {'name': 'hem', 'size': 251},
#   {'name': 'liver function deterioration', 'size': 3},
#   {'name': 'novel coronavirus', 'size': 178},
#   {'name': 'p effusion', 'size': 7},
#   {'name': 'pancreatitis', 'size': 94},
#   {'name': 'parasitic infections', 'size': 7},
#   {'name': 'placental vasculopathy', 'size': 6},
#   {'name': 'pulmonary hypertension', 'size': 92},
#   {'name': 'vascular , cardiac and cutaneous responses', 'size': 2},
#   {'name': 'ventricular arrhythmias', 'size': 59},
#   {'name': 'COVID ) of', 'size': 2},
#   {'name': 'COVID - 19 pneumonia', 'size': 2415},
#   {'name': 'DV', 'size': 27},
#   {'name': 'IgM', 'size': 1448},
#   {'name': 'Kawasaki - like shock', 'size': 2},
#   {'name': 'Novel Coronavirus Disease 2019', 'size': 4},
#   {'name': 'SARS - Co inflammation', 'size': 1},
#   {'name': 'SL', 'size': 36},
#   {'name': 'VTEhrosis', 'size': 1},
#   {'name': 'acute myocarditis', 'size': 36},
#   {'name': 'bilateral lung infiltration', 'size': 1},
#   {'name': 'chronic ill', 'size': 1},
#   {'name': 'coronavirus disease 2019D', 'size': 109},
#   {'name': 'coronavirus diseaseD', 'size': 513},
#   {'name': 'emerging coronavirus disease', 'size': 11},
#   {'name': 'humanogenic covirus', 'size': 2},
#   {'name': 'inflammatory disease', 'size': 26},
#   {'name': 'influenza like', 'size': 1},
#   {'name': 'lary', 'size': 12},
#   {'name': 'medical conditions', 'size': 45},
#   {'name': 'microvascular injury', 'size': 6},
#   {'name': 'neurologic disorders', 'size': 11},
#   {'name': 'oncologic or limb', 'size': 2},
#   {'name': 'post - traumatic stress', 'size': 38},
#   {'name': 'respiratory , physical , and psychological dysfunction',
#    'size': 4},
#   {'name': 'taste and smell alterations', 'size': 6},
#   {'name': 'upper respiratory tract symptoms', 'size': 12},
#   {'name': 'vascular complications', 'size': 30},
#   {'name': 'COVID - 19 health', 'size': 12},
#   {'name': 'COVID of', 'size': 4},
#   {'name': 'Immde', 'size': 2},
#   {'name': 'SARS - CoV - 2 viral', 'size': 12},
#   {'name': 'STEMI', 'size': 477},
#   {'name': 'Sudden olfactory dysfunction', 'size': 4},
#   {'name': 'alcohol use disorder', 'size': 18},
#   {'name': 'cardio - metabolic disease', 'size': 3},
#   {'name': 'cardiothoracic conditions', 'size': 2},
#   {'name': 'covirus 2019 infection', 'size': 5},
#   {'name': 'critical', 'size': 74},
#   {'name': 'damp - toxin', 'size': 2},
#   {'name': 'hypersensitivity', 'size': 20},
#   {'name': 'hyponat', 'size': 1},
#   {'name': 'liquor plant', 'size': 1},
#   {'name': 'lower respiratory illness', 'size': 3},
#   {'name': 'lung functional disability', 'size': 2},
#   {'name': 'nasal', 'size': 17},
#   {'name': 'oy impairments', 'size': 2},
#   {'name': 'panic , anxiety', 'size': 1},
#   {'name': 'physical dysfunction', 'size': 2},
#   {'name': 'preDM', 'size': 1},
#   {'name': 'psychiatric disorders', 'size': 161},
#   {'name': 'severe coronavirus disease', 'size': 106},
#   {'name': 'upper respiratory and / or influenza - like illness', 'size': 2},
#   {'name': 'vlit', 'size': 3},
#   {'name': 'xerosis cutis', 'size': 4},
#   {'name': 'BS', 'size': 34},
#   {'name': 'Coagulation abnormalities', 'size': 8},
#   {'name': 'Coronavirus infection 2019', 'size': 2},
#   {'name': 'GU cancer', 'size': 6},
#   {'name': 'TB', 'size': 428},
#   {'name': 'anxiety and stress disorder', 'size': 3},
#   {'name': 'arterial and venous thromboembolism', 'size': 16},
#   {'name': 'benign prostate hyperplasia', 'size': 2},
#   {'name': 'co disease', 'size': 23},
#   {'name': 'coronavirus 2', 'size': 129},
#   {'name': 'diabetes mellitusVID - 19', 'size': 2},
#   {'name': 'flutter', 'size': 4},
#   {'name': 'hypovitaminosis D', 'size': 19},
#   {'name': 'loss of and', 'size': 4},
#   {'name': 'low grade fever', 'size': 8},
#   {'name': 'manic - like', 'size': 2},
#   {'name': 'ne', 'size': 579},
#   {'name': 'physical in', 'size': 24},
#   {'name': 'pulmonary dysbiosis', 'size': 1},
#   {'name': 'systemic diseases', 'size': 32},
#   {'name': 'thyroid dysfunction', 'size': 8},
#   {'name': 'vere acute syndrome Coronavirus2', 'size': 1},
#   {'name': 'Acute respiratory distress syndrome', 'size': 101},
#   {'name': 'BCvirus', 'size': 1},
#   {'name': 'Covirus /', 'size': 3},
#   {'name': 'Hemophagocytic lymphohistiocytosis', 'size': 9},
#   {'name': 'RRMS', 'size': 20},
#   {'name': 'Se or - Threning disease', 'size': 2},
#   {'name': 'Severe Acute Respiratory Syndrome Co 2', 'size': 15},
#   {'name': 'adrenal crisis', 'size': 5},
#   {'name': 'coronavirus - 2019 disease', 'size': 5},
#   {'name': 'de of lung function', 'size': 2},
#   {'name': 'diabetic retinopathy', 'size': 32},
#   {'name': 'dialysis', 'size': 7},
#   {'name': 'emotional disorders', 'size': 15},
#   {'name': 'gasintest symptoms', 'size': 3},
#   {'name': 'haoptysis', 'size': 9},
#   {'name': 'humans 2019', 'size': 4},
#   {'name': 'infertility', 'size': 69},
#   {'name': 'kidney failure', 'size': 47},
#   {'name': 'malai', 'size': 38},
#   {'name': 'malaria related', 'size': 2},
#   {'name': 'multisystemic inflammatory syndrome', 'size': 20},
#   {'name': 'physical , functional , cognitive , and mental health decline',
#    'size': 2},
#   {'name': 'ps', 'size': 74},
#   {'name': 'severe acute respiratory coronavirus virus 2', 'size': 19},
#   {'name': 'sore throat of taste', 'size': 1},
#   {'name': 'speech - language path', 'size': 1},
#   {'name': 'vomiting', 'size': 446},
#   {'name': 'Acute lung injury', 'size': 15},
#   {'name': 'COronaVIrus Disease 19', 'size': 15},
#   {'name': 'Cervical cancer', 'size': 5},
#   {'name': 'EP', 'size': 46},
#   {'name': 'Lung disease', 'size': 5},
#   {'name': 'PLHI', 'size': 8},
#   {'name': 'SARS - Co - 2 disease', 'size': 4},
#   {'name': 'SARS - CoV - 2 spike S2 subunit', 'size': 2},
#   {'name': 'SARS - CoV2 infection', 'size': 108},
#   {'name': 'acute chest syndrome', 'size': 12},
#   {'name': 'acute demyelination and encephalitis', 'size': 2},
#   {'name': 'allergic disorders', 'size': 4},
#   {'name': 'burn', 'size': 283},
#   {'name': 'chronic physical conditions', 'size': 4},
#   {'name': 'economic depression', 'size': 10},
#   {'name': 'infectious acute abdomen', 'size': 5},
#   {'name': 'inflammatory bowel diseases', 'size': 28},
#   {'name': 'lung and heart injuries', 'size': 1},
#   {'name': 'mcum contag', 'size': 2},
#   {'name': 'mesothelioma', 'size': 2},
#   {'name': 'musculoskeletal dysfunction', 'size': 2},
#   {'name': 'overall tired', 'size': 1},
#   {'name': 'psychotic symptoms', 'size': 41},
#   {'name': 'respiratory distress syndrome hypoxia', 'size': 4},
#   {'name': 'respiratory or circulatory failure', 'size': 4},
#   {'name': 'rheumatic diseases rumatic', 'size': 1},
#   {'name': 's production', 'size': 12},
#   {'name': 'sleep problems', 'size': 63},
#   {'name': 'sudden cardiac death', 'size': 29},
#   {'name': 'upper respiratory', 'size': 20},
#   {'name': 'urological conditions', 'size': 18},
#   {'name': 'viral infection and', 'size': 2},
#   {'name': 'β - thalassemia', 'size': 7},
#   {'name': 'COVID - 19 hypoxemia', 'size': 1},
#   {'name': 'Food ins', 'size': 12},
#   {'name': 'Legionella infections', 'size': 2},
#   {'name': 'MERS - CoV , and', 'size': 2},
#   {'name': 'SARS - COV1', 'size': 3},
#   {'name': 'SARS - COV2', 'size': 102},
#   {'name': 'SARS - Cov - 2 2019', 'size': 3},
#   {'name': 'Severe Acute Re Sdrome Coronavirus', 'size': 3},
#   {'name': 'Severe Acute Re Syndrome coronavirus', 'size': 2},
#   {'name': 'Severe Acute Respiratory Syndrome co', 'size': 45},
#   {'name': 'acute infection of the respiratory tract', 'size': 3},
#   {'name': 'autoimmune disorders', 'size': 36},
#   {'name': 'cardiac and vascular complications', 'size': 2},
#   {'name': 'common cold', 'size': 123},
#   {'name': 'food and nutritional ins', 'size': 4},
#   {'name': 'ha instability', 'size': 2},
#   {'name': 'hilar lymphadenopathy', 'size': 3},
#   {'name': 'hypoxemic respiratory failure', 'size': 91},
#   {'name': 'lung pneumonia', 'size': 5},
#   {'name': 'men', 'size': 1918},
#   {'name': 'neurological problems', 'size': 10},
#   {'name': 'novel corona virus - 19', 'size': 2},
#   {'name': 'oral and maxillofa', 'size': 4},
#   {'name': 'psychiatric and physical disorders', 'size': 2},
#   {'name': 're infarction', 'size': 1},
#   {'name': 'rheumatic musculoskeletal diseases', 'size': 2},
#   {'name': 'systemic thrombotic microangiopathy', 'size': 3},
#   {'name': '2019 - nCoV /', 'size': 17},
#   {'name': '2019 - nCoV 2019', 'size': 5},
#   {'name': 'AM', 'size': 113},
#   {'name': 'Corona Virus Disease − 19', 'size': 2},
#   {'name': 'Covirus infectious disease 2019', 'size': 3},
#   {'name': 'DCI', 'size': 15},
#   {'name': 'Dengue virus', 'size': 15},
#   {'name': 'Neurological', 'size': 4},
#   {'name': 'Neurological complications', 'size': 20},
#   {'name': 'Novel coronavirus disease 19', 'size': 2},
#   {'name': 'Pneumonia Hypertension', 'size': 1},
#   {'name': 'cardiac abnormalities', 'size': 15},
#   {'name': 'cardiovascular metabolic diseases', 'size': 8},
#   {'name': 'cirrhosis', 'size': 139},
#   {'name': 'comoribities', 'size': 1},
#   {'name': 'consolidations', 'size': 2},
#   {'name': 'coronravirus disease', 'size': 2},
#   {'name': 'decompensation', 'size': 3},
#   {'name': 'disabilities', 'size': 146},
#   {'name': 'emerging 2019 coronavirus disease', 'size': 2},
#   {'name': 'epidermal and dermal vascular lesions', 'size': 1},
#   {'name': 'immune - mediated multiorgan damage', 'size': 2},
#   {'name': 'nepsychiatric com', 'size': 1},
#   {'name': 'neuropathy', 'size': 21},
#   {'name': 'nonspecific myocardial injury', 'size': 3},
#   {'name': 'novel coronavirus ( COVID - 19 ) disease', 'size': 4},
#   {'name': 'novel covirus disease - 2019', 'size': 4},
#   {'name': 'pre - gestational diabetes', 'size': 2},
#   {'name': 'psopology', 'size': 2},
#   {'name': 'structural and congenital heart diseases', 'size': 2},
#   {'name': 'terminal respiratory distress', 'size': 3},
#   {'name': 'AA', 'size': 117},
#   {'name': 'CD4 *', 'size': 1},
#   {'name': 'COD', 'size': 1631},
#   {'name': 'COVID - 19 virus', 'size': 508},
#   {'name': 'Coovus 2019', 'size': 1},
#   {'name': 'Multisystem Inflammatory Syndrome', 'size': 38},
#   {'name': 'Novel corona virus disease', 'size': 2},
#   {'name': 'SARS - liked', 'size': 1},
#   {'name': 'Severe acute respiratory syndromedemic coronavirus 2019 disease',
#    'size': 1},
#   {'name': 'cerebrovascular ischemic stroke', 'size': 2},
#   {'name': 'fragility fractures', 'size': 12},
#   {'name': 'gastrointestinal ( GI ) and liver diseases', 'size': 2},
#   {'name': 'hcoable state', 'size': 4},
#   {'name': 'hypercytokinaemia', 'size': 7},
#   {'name': 'impaired', 'size': 33},
#   {'name': 'liver failure', 'size': 39},
#   {'name': 'nelogical complications', 'size': 16},
#   {'name': 'preterm delivery', 'size': 35},
#   {'name': 'prolonged grief disorder', 'size': 10},
#   {'name': 'psychotic', 'size': 38},
#   {'name': 'pulmonary and cardiovascular adverse events', 'size': 2},
#   {'name': 'pulmonary infections', 'size': 21},
#   {'name': 'respiratory and cardiac compromise', 'size': 3},
#   {'name': 'respiratory involvement', 'size': 27},
#   {'name': 'severe acute respiratory syndrome corona - virus 2', 'size': 2},
#   {'name': 'systemic hypotension', 'size': 3},
#   {'name': 'venous and arterial thbotic complications', 'size': 1},
#   {'name': 'virus 2019 disease', 'size': 3},
#   {'name': 'DR', 'size': 67},
#   {'name': 'Home', 'size': 6},
#   {'name': 'MODS', 'size': 42},
#   {'name': 'Middle East respiratory', 'size': 5},
#   {'name': 'Novel covirus disease', 'size': 6},
#   {'name': 'RA', 'size': 891},
#   {'name': 'SAPHO', 'size': 2},
#   {'name': 'Sleep disorders', 'size': 7},
#   {'name': 'Trans sinus bradycardia', 'size': 1},
#   {'name': 'VTE', 'size': 595},
#   {'name': 'atherosclerosis', 'size': 52},
#   {'name': 'autoimmune or systemic inflammatory disease', 'size': 2},
#   {'name': 'blood colation disorder', 'size': 2},
#   {'name': 'burnout', 'size': 241},
#   {'name': 'cardmet LTC', 'size': 1},
#   {'name': 'chest infections', 'size': 3},
#   {'name': 'del', 'size': 25},
#   {'name': 'depression and anxiety disorders', 'size': 3},
#   {'name': 'gustatory and olfactory dysfunctions', 'size': 1},
#   {'name': 'human in', 'size': 2},
#   {'name': 'infectious disease', 'size': 1973},
#   {'name': 'lactic acidosis', 'size': 5},
#   {'name': 'life - limiting illness', 'size': 2},
#   {'name': 'liver cirrhosis', 'size': 29},
#   {'name': 'mental health conditions', 'size': 50},
#   {'name': 'pharyngeal congestion', 'size': 1},
#   {'name': 'pressure ulcers', 'size': 11},
#   {'name': 'severe covirus disease - 2019', 'size': 1},
#   {'name': 'taste loss loss', 'size': 1},
#   {'name': 'thbotic com', 'size': 4},
#   {'name': 'thrombo - embolism', 'size': 5},
#   {'name': 'COVID - 19 infectious diseases', 'size': 2},
#   {'name': 'COVID - 19 syndrome Coronavirus 2', 'size': 1},
#   {'name': 'CRTH2', 'size': 3},
#   {'name': 'Dysgeusia', 'size': 6},
#   {'name': 'Ebola AIDS', 'size': 1},
#   {'name': 'Gynecologic malignancies', 'size': 2},
#   {'name': 'IPV', 'size': 78},
#   {'name': 'Infectious Diseases ofverty', 'size': 2},
#   {'name': 'Mental health difficulties', 'size': 2},
#   {'name': 'OP', 'size': 19},
#   {'name': 'PF', 'size': 31},
#   {'name': 'SARS - Cov - 2virus', 'size': 3},
#   {'name': 'SARS coronavirus', 'size': 96},
#   {'name': 'VTElogic complications', 'size': 1},
#   {'name': 'chronic conditions', 'size': 128},
#   {'name': 'cognitive and emotional disorders', 'size': 2},
#   {'name': 'constitutional and respiratory symptoms', 'size': 3},
#   {'name': 'dawn curfew', 'size': 1},
#   {'name': 'dengue virus', 'size': 57},
#   {'name': 'dig system', 'size': 4},
#   {'name': 'em', 'size': 42},
#   {'name': 'g', 'size': 151},
#   {'name': 'hypervisity', 'size': 1},
#   {'name': 'hypovolemic hyponatremia', 'size': 3},
#   {'name': 'immune system dysfunction', 'size': 7},
#   {'name': 'imp', 'size': 25},
#   {'name': 'lung cancer', 'size': 460},
#   {'name': 'neurodegenerative and cardiac disorders', 'size': 2},
#   {'name': 'neurodegenerative disorders', 'size': 17},
#   {'name': 'oncological', 'size': 38},
#   {'name': 'pneonic in', 'size': 7},
#   {'name': 'pulmonary diffuse alveolar damage', 'size': 2},
#   {'name': 'right ventricular dysfunction', 'size': 17},
#   {'name': 'severe acute respiratory coronavirus syndrome 2', 'size': 2},
#   {'name': 'systemic multiorgan dysfunction syndrome', 'size': 2},
#   {'name': 'ACS', 'size': 207},
#   {'name': 'Alzheimer ’ s disease', 'size': 23},
#   {'name': 'COMT Val ( 158 ) Met4680 functionalphism', 'size': 1},
#   {'name': 'HCC', 'size': 73},
#   {'name': 'Novel Corona virus - 19', 'size': 2},
#   {'name': 'SARS - CoV - 2 ) viral infection', 'size': 3},
#   {'name': 'SARS Coronavirus', 'size': 5},
#   {'name': 'Severe Acute Retory Syndrome Corona virus 2', 'size': 1},
#   {'name': 'autism', 'size': 43},
#   {'name': 'brain involvement', 'size': 9},
#   {'name': 'cardiac pathologies', 'size': 4},
#   {'name': 'cardiogenic and vasoplegic shock', 'size': 2},
#   {'name': 'coronavirus infection disease', 'size': 6},
#   {'name': 'extrapulmonary conditions', 'size': 2},
#   {'name': 'fe seizures', 'size': 8},
#   {'name': 'h multi - organ thromboembolic storm', 'size': 2},
#   {'name': 'in virus', 'size': 77},
#   {'name': 'low', 'size': 41},
#   {'name': 'lung infections', 'size': 42},
#   {'name': 'mic coronavirus disease 2019', 'size': 2},
#   {'name': 'mucormycosis', 'size': 9},
#   {'name': 'pont pneumothorax', 'size': 1},
#   {'name': 'primary kidney disease', 'size': 2},
#   {'name': 'renal masses', 'size': 11},
#   {'name': 'thrombotic or neurologic events', 'size': 2},
#   {'name': 'B wall thick', 'size': 1},
#   {'name': 'C - involvement', 'size': 2},
#   {'name': 'COVID ’ s - 19', 'size': 1},
#   {'name': 'Chagas disease', 'size': 7},
#   {'name': 'GIB', 'size': 28},
#   {'name': 'IB', 'size': 41},
#   {'name': 'Mycopma pneumoniae', 'size': 13},
#   {'name': 'aortic valve disease', 'size': 1},
#   {'name': 'coronavirus disease 2019 ( COVID - 19 )', 'size': 9},
#   {'name': 'depressive symptoms', 'size': 375},
#   {'name': 'foral fragility fracture', 'size': 1},
#   {'name': 'influenza', 'size': 1756},
#   {'name': 'macrophage activation syndrome', 'size': 70},
#   {'name': 'multi conditions', 'size': 1},
#   {'name': 'myocardial or vascular dysfunction', 'size': 1},
#   {'name': 'pancreatic injury', 'size': 17},
#   {'name': 'systemic CRS', 'size': 1},
#   {'name': 'thbo - embolic events', 'size': 3},
#   {'name': 'urologic disease', 'size': 2},
#   {'name': '2019 - novel coronavirus', 'size': 29},
#   {'name': 'Angiotensin - Converting Enzyme - 2', 'size': 2},
#   {'name': 'Autoimmune encephalitis', 'size': 1},
#   {'name': 'COVID - 19 vasculopathy', 'size': 2},
#   {'name': 'CVMs', 'size': 8},
#   {'name': 'F', 'size': 322},
#   {'name': 'Hyposmia', 'size': 12},
#   {'name': 'Nsp15', 'size': 28},
#   {'name': 'SARS - CoV2 infections', 'size': 6},
#   {'name': 'arrythmias', 'size': 3},
#   {'name': 'catab distress', 'size': 2},
#   {'name': 'co disease - 2019', 'size': 4},
#   {'name': 'gasintestinal', 'size': 3},
#   {'name': 'horse', 'size': 16},
#   {'name': 'ic', 'size': 13},
#   {'name': 'imup', 'size': 6},
#   {'name': 'lion', 'size': 5},
#   {'name': 'm obesity', 'size': 21},
#   {'name': 'malnutrition ins', 'size': 2},
#   {'name': 'meningoencephalitis', 'size': 51},
#   {'name': 'obesity', 'size': 1771},
#   {'name': 'olfactory loss', 'size': 63},
#   {'name': 'opioid crisis', 'size': 3},
#   {'name': 'pneocyte hyperp', 'size': 2},
#   {'name': 'sHLH', 'size': 27},
#   {'name': 'serious', 'size': 3},
#   {'name': 'severe Coronavirus Disease 2019', 'size': 9},
#   {'name': 'DC', 'size': 36},
#   {'name': 'Delirium', 'size': 81},
#   {'name': 'MERS SARS', 'size': 1},
#   {'name': 'Olfactory disorders', 'size': 4},
#   {'name': 'On', 'size': 25},
#   {'name': 'SARS - CoV - 2 induced Coronavirus disease - 19', 'size': 1},
#   {'name': 'VTED', 'size': 2},
#   {'name': 'acute gastroenteritis', 'size': 11},
#   {'name': 'aggressive non - Hodgkin lymphoma', 'size': 2},
#   {'name': 'bloody diarrhea', 'size': 2},
#   {'name': 'cardioembolic disease', 'size': 2},
#   {'name': 'com', 'size': 50},
#   {'name': 'dig', 'size': 131},
#   {'name': 'equine coronavirus', 'size': 2},
#   {'name': 'hypersensitivity pneumonitis', 'size': 4},
#   {'name': 'hypoprealbuminemia', 'size': 2},
#   {'name': 'nasal congestion', 'size': 107},
#   {'name': 'nein', 'size': 33},
#   {'name': 'novel 2019 coronavirus disease', 'size': 13},
#   {'name': 'novel coronavirus illness', 'size': 1},
#   {'name': 'olfactory and gatory dysfunctions', 'size': 4},
#   {'name': 'pandemic infectious disease', 'size': 10},
#   {'name': 'pulmonary thromboembolism', 'size': 47},
#   {'name': 'rash', 'size': 126},
#   {'name': 'severe acute respiratory syndrome - co', 'size': 24},
#   {'name': 'Corona - Virus - Disease - 19', 'size': 2},
#   {'name': 'DMD', 'size': 18},
#   {'name': 'SARS - Cov - 2', 'size': 761},
#   {'name': 'SIC', 'size': 24},
#   {'name': 'acute arterial ischemia', 'size': 6},
#   {'name': 'atopic dermatitis', 'size': 64},
#   {'name': 'bowel incontinence', 'size': 3},
#   {'name': 'cardiac injury', 'size': 371},
#   {'name': 'cardiovascular conditionsble diseases', 'size': 2},
#   {'name': 'cardiovascular damage', 'size': 25},
#   {'name': 'chronic cardiopulmonary diseases', 'size': 3},
#   {'name': 'corona - virus disease', 'size': 11},
#   {'name': 'covirus pneumonia', 'size': 260},
#   {'name': 'crisis of Coronavirus Disease 2019', 'size': 2},
#   {'name': 'endocrine disorders', 'size': 17},
#   {'name': 'hematology - oncology disease', 'size': 4},
#   {'name': 'immune system path', 'size': 1},
#   {'name': 'liquor', 'size': 2},
#   {'name': 'loss of consciousness', 'size': 31},
#   {'name': 'nCoV396', 'size': 2},
#   {'name': 'necrotising pneumonia', 'size': 3},
#   {'name': 'novelronavirus disease 2019', 'size': 3},
#   {'name': 'otitis ex', 'size': 1},
#   {'name': 'respiratory and gastrointestinal', 'size': 6},
#   {'name': 's flu', 'size': 15},
#   {'name': 'sarcoidosis', 'size': 20},
#   {'name': 'scotoma', 'size': 1},
#   {'name': 'systemic inflammation', 'size': 121},
#   {'name': 'thrombosis', 'size': 822},
#   {'name': 'Coronavirus disease - 19', 'size': 79},
#   {'name': 'LTC', 'size': 22},
#   {'name': 'MERS - Cov', 'size': 8},
#   {'name': 'RDV', 'size': 73},
#   {'name': 'SAR - CoV - 2 infections', 'size': 3},
#   {'name': 'acute respiratory deterioration', 'size': 5},
#   {'name': 'arterial and venous thrombotic events', 'size': 1},
#   {'name': 'blood hypercoability', 'size': 1},
#   {'name': 'by', 'size': 11},
#   {'name': 'coagulation disorder', 'size': 16},
#   {'name': 'corona viral infection diseases', 'size': 1},
#   {'name': 'ectal', 'size': 2},
#   {'name': 'hand', 'size': 2},
#   {'name': 'hypogeusia', 'size': 73},
#   {'name': 'immune dysfunction', 'size': 30},
#   {'name': 'ischemic stroke', 'size': 221},
#   {'name': 'mali', 'size': 20},
#   {'name': 'mic coronavirus', 'size': 2},
#   {'name': 'myopia', 'size': 23},
#   {'name': 'novel corona virus disease 2019', 'size': 8},
#   {'name': 'organ damage failure', 'size': 4},
#   {'name': 'proteinuria', 'size': 118},
#   {'name': 'severe acute respiratory syndrome novel coronavirus - 2',
#    'size': 2},
#   {'name': 'severe acute respiratory syndrome – coronavirus - 2', 'size': 6},
#   {'name': 'systemic thrombotic complications', 'size': 2},
#   {'name': 'virus syndrome disease', 'size': 1},
#   {'name': 'Covirus - 19 disease', 'size': 4},
#   {'name': 'Panmic coronavirus disease 2019', 'size': 3},
#   {'name': 'Rhabdomyolysis', 'size': 8},
#   {'name': 'SARS - CoV - 2virus 19', 'size': 1},
#   {'name': 'Throembolic events', 'size': 2},
#   {'name': 'abnormalities of liver function', 'size': 4},
#   {'name': 'altered', 'size': 34},
#   {'name': 'autoimmune and rheumatic mloskeletal', 'size': 2},
#   {'name': 'chblains', 'size': 27},
#   {'name': 'chronic GVHD', 'size': 4},
#   {'name': 'coronary artery disease', 'size': 145},
#   {'name': 'covirus disease of', 'size': 17},
#   {'name': 'diabetic condition', 'size': 2},
#   {'name': 'interstitial bilateral pneumonia', 'size': 7},
#   {'name': 'lopenia responses', 'size': 1},
#   {'name': 'nasal symptoms', 'size': 10},
#   {'name': 'nepsy', 'size': 7},
#   {'name': 'non', 'size': 37},
#   {'name': 'non - communicable disease', 'size': 17},
#   {'name': 'respiratory inflammation', 'size': 5},
#   {'name': 'respiratory muscle weakness', 'size': 4},
#   {'name': 'sneezing', 'size': 19},
#   {'name': 'tuberculosis disease', 'size': 3},
#   {'name': '2019', 'size': 742},
#   {'name': 'C /Q poisoning', 'size': 1},
#   {'name': 'Crohn ’ s Disease', 'size': 3},
#   {'name': 'In violence', 'size': 4},
#   {'name': 'MERS - CoV', 'size': 1704},
#   {'name': 'MERS CoV', 'size': 75},
#   {'name': 'Novel coronavirus', 'size': 20},
#   {'name': 'PD', 'size': 433},
#   {'name': 'Pneumothoraces', 'size': 2},
#   {'name': 'SARS - CoV - 2 S', 'size': 44},
#   {'name': 'SARS - CoV - 2 coronavirus', 'size': 61},
#   {'name': 'SARS - CoV - 2virus Disease - 19', 'size': 3},
#   {'name': 'Severe Acute Respiratory Syndrome Covirus', 'size': 11},
#   {'name': 'acute behavioral changes', 'size': 2},
#   {'name': 'at pneumonia', 'size': 72},
#   {'name': 'autonomic dysfunction', 'size': 4},
#   {'name': 'chose loss', 'size': 2},
#   {'name': 'chronic underlying diseases', 'size': 4},
#   {'name': 'coronavirus diseaseVID', 'size': 733},
#   {'name': 'covirus disease - 2019', 'size': 223},
#   {'name': 'distress', 'size': 183},
#   {'name': 'gastrointestinal bleeding', 'size': 37},
#   {'name': 'gynecological malignant tumors', 'size': 6},
#   {'name': 'infectious diseases', 'size': 1630},
#   {'name': 'lung and multi - organ damage', 'size': 1},
#   {'name': 'lung endothelial injury', 'size': 2},
#   {'name': 'new coronavirus disease', 'size': 36},
#   {'name': 're', 'size': 561},
#   {'name': 'respiratory diseases', 'size': 301},
#   {'name': 'right ventricular failure', 'size': 14},
#   {'name': 'severe acute respiratory syndrome corona', 'size': 57},
#   {'name': 'systemic autoimmune diseases', 'size': 14},
#   {'name': 'COVD', 'size': 27},
#   {'name': 'CVI', 'size': 10},
#   {'name': 'HIT', 'size': 50},
#   {'name': 'IBDs', 'size': 6},
#   {'name': 'SARS - Cov - 2 infection', 'size': 51},
#   {'name': 'SARS and H1N1 influenza', 'size': 2},
#   {'name': 'Throtic complications', 'size': 11},
#   {'name': 'Wuhan pneumonia virus', 'size': 1},
#   {'name': 'airway diseases', 'size': 5},
#   {'name': 'arr', 'size': 47},
#   {'name': 'coronavirus disease 2019VID - 19', 'size': 37},
#   {'name': 'digestive system tumors', 'size': 1},
#   {'name': 'flaccid paraparesis', 'size': 3},
#   {'name': 'gastric cancer', 'size': 12},
#   {'name': 'head and neck cancer', 'size': 161},
#   {'name': 'hyperinflammation syndrome', 'size': 8},
#   {'name': 'infectious peritonitis', 'size': 27},
#   {'name': 'interstitial pneumonia', 'size': 244},
#   {'name': 'liver damage dysfunction', 'size': 7},
#   {'name': 'lung contusion', 'size': 8},
#   {'name': 'noncomnicable diseases', 'size': 14},
#   {'name': 'oy loss', 'size': 16},
#   {'name': 'pain discomfort', 'size': 2},
#   {'name': 'pulmonary and distal coagulopathies', 'size': 3},
#   {'name': 'respiratory changes', 'size': 1},
#   {'name': 'sudden unexpected death', 'size': 3},
#   {'name': 'thromboembolism', 'size': 169},
#   {'name': 'COIVD - 19', 'size': 27},
#   {'name': 'COronaVirus Disease 2019', 'size': 2},
#   {'name': 'Corona virus', 'size': 97},
#   {'name': 'MSICH', 'size': 10},
#   {'name': 'Nological', 'size': 3},
#   {'name': 'Olfactory / gatory disorders', 'size': 2},
#   {'name': 'Oral and maxillofacial', 'size': 3},
#   {'name': 'SARS - 2002', 'size': 1},
#   {'name': 'SARS - CoV - 2virus disease 2019', 'size': 30},
#   {'name': 'SIADH', 'size': 13},
#   {'name': 'SM', 'size': 34},
#   {'name': 'SOB', 'size': 20},
#   {'name': 'SSE', 'size': 1},
#   {'name': 'co dys', 'size': 5},
#   {'name': 'coagulopathyhr', 'size': 2},
#   {'name': 'covirus 19', 'size': 22},
#   {'name': 'cting and thrombotic complications', 'size': 1},
#   {'name': 'emerging infectious diseases', 'size': 10},
#   {'name': 'gasintestinal symptoms', 'size': 2},
#   {'name': 'influenza like illness', 'size': 19},
#   {'name': 'pandemic influenza', 'size': 16},
#   {'name': 'rheumatoid arthritis', 'size': 176},
#   {'name': 'severe asthma', 'size': 9},
#   {'name': 'systemic illness', 'size': 8},
#   {'name': 'taste and smell loss', 'size': 7},
#   {'name': 'transplant rejection', 'size': 3},
#   {'name': '2019 - nCoV virus', 'size': 19},
#   {'name': '2019 Coronavirus disease', 'size': 6},
#   {'name': 'Corona Virus Disease of 2019', 'size': 2},
#   {'name': 'Covirus infection', 'size': 17},
#   {'name': 'H1', 'size': 73},
#   {'name': 'SARS - CoV - 2virus', 'size': 70},
#   {'name': 'Severe Acute Respiratory Syndrome coronavirus 2 (', 'size': 2},
#   {'name': 'acute hyperinflammatory syndrome', 'size': 1},
#   {'name': 'at heart', 'size': 1},
#   {'name': 'cardiometab', 'size': 4},
#   {'name': 'category A infectious diseases', 'size': 2},
#   {'name': 'chronic commodities', 'size': 1},
#   {'name': 'co - virus', 'size': 3},
#   {'name': 'colecistitis a', 'size': 2},
#   {'name': 'liver enzyme derangement', 'size': 2},
#   {'name': 'physical exhaustion', 'size': 6},
#   {'name': 'respiratory problems', 'size': 32},
#   {'name': 'restrictive lung disease', 'size': 2},
#   {'name': 'COVID - 19 cough', 'size': 8},
#   {'name': 'HB infection', 'size': 3},
#   {'name': 'In', 'size': 171},
#   {'name': 'Severecutedrome Coronavirus 2', 'size': 3},
#   {'name': 'Sjogren ’ s syndrome', 'size': 1},
#   {'name': 'VitD deficiency', 'size': 6},
#   {'name': 'altered sense of smell', 'size': 2},
#   {'name': 'arrhythmia', 'size': 271},
#   {'name': 'cGVHD', 'size': 2},
#   {'name': 'chest radiographic abnormal', 'size': 3},
#   {'name': 'chronic respiratory disease', 'size': 36},
#   {'name': 'diffuse alveolar hemorrhage', 'size': 4},
#   {'name': 'economic anxiety', 'size': 8},
#   {'name': 'multi - organ damage', 'size': 12},
#   {'name': 'novel covirus 2019', 'size': 18},
#   {'name': 'pregnancy', 'size': 26},
#   {'name': 'pulmonary thrombotic complications', 'size': 1},
#   {'name': 'sepsis', 'size': 712},
#   {'name': 'ters', 'size': 14},
#   {'name': 'type 2 diabetes mellitus', 'size': 89},
#   {'name': '2019 - noV', 'size': 20},
#   {'name': 'Hereditary Haemorrhagic Telangiectasia', 'size': 2},
#   {'name': 'Infect Disease', 'size': 16},
#   {'name': 'SARS ) - CoV - 2', 'size': 46},
#   {'name': 'SARS - CoV - 19', 'size': 35},
#   {'name': 'SARS - CoV - 2ronavirus disease', 'size': 1},
#   {'name': 'SARS CoV - 2p', 'size': 2},
#   {'name': 'Severe and critical coronavirus pneumonia 2019', 'size': 2},
#   {'name': 'arrhy', 'size': 18},
#   {'name': 'chronic renal disorders', 'size': 1},
#   {'name': 'coagulopathies', 'size': 42},
#   {'name': 'diffuse petechial cerebral haemorrhage', 'size': 2},
#   {'name': 'heart failure', 'size': 635},
#   {'name': 'hemodialys', 'size': 6},
#   {'name': 'household dysfunction', 'size': 2},
#   {'name': 'hypertens', 'size': 28},
#   {'name': 'impaired function', 'size': 8},
#   {'name': 'insufficiency', 'size': 3},
#   {'name': 'involvement', 'size': 11},
#   {'name': 'lung inflammation', 'size': 119},
#   {'name': 'man', 'size': 717},
#   {'name': 'mental problems', 'size': 19},
#   {'name': 'non - COVID viral pneumonia', 'size': 6},
#   {'name': 'novel coronavirus disease of 2019', 'size': 8},
#   {'name': 'post - infective lung damage', 'size': 2},
#   {'name': 'pulmonary and cardiovascular complications', 'size': 4},
#   {'name': 'renal injury', 'size': 36},
#   {'name': 'rheumatic', 'size': 129},
#   {'name': 'rhinovirus', 'size': 10},
#   {'name': 'vere acute respiratory syndrome coronavirus - 2', 'size': 3},
#   {'name': 'violaceous and puular lesions', 'size': 1},
#   {'name': 'virus 2', 'size': 34},
#   {'name': 'Acute Retory Syndrome Coronavirus', 'size': 2},
#   {'name': 'COD - 19 19D - 19', 'size': 2},
#   {'name': 'COVI 19', 'size': 712},
#   {'name': 'Cerebrovascular Disease', 'size': 3},
#   {'name': 'Coronavirus - 19', 'size': 26},
#   {'name': 'PwDs', 'size': 11},
#   {'name': 'SA - Co 2', 'size': 66},
#   {'name': 'SARS - CoV - 2 ) virus disease 2019', 'size': 1},
#   {'name': 'ST - elevation MI', 'size': 3},
#   {'name': 'Se Acute Respiratory Syndrome', 'size': 32},
#   {'name': 'acquired immunodeficiency syndrome', 'size': 17},
#   {'name': 'd of', 'size': 4},
#   {'name': 'de and anxiety symptoms', 'size': 5},
#   {'name': 'diabetes mellitus type 2', 'size': 4},
#   {'name': 'epiglottitis', 'size': 5},
#   {'name': 'flu infections', 'size': 3},
#   {'name': 'muscle soreness', 'size': 23},
#   {'name': 'renal failure', 'size': 107},
#   {'name': 'severe acute respiratory syndrome corona - virus', 'size': 1},
#   {'name': 'thy', 'size': 22},
#   {'name': 'β - CoVvirus', 'size': 1},
#   {'name': 'AT', 'size': 98},
#   {'name': 'Acute Reiratory Syndrome coronavirus 2', 'size': 2},
#   {'name': 'COVID - 19 im', 'size': 2},
#   {'name': 'COVID - 19 lung infection', 'size': 5},
#   {'name': 'Chronic Kidney Disease', 'size': 4},
#   {'name': 'H1N1 influenza infection', 'size': 3},
#   {'name': 'allergy', 'size': 87},
#   {'name': 'beds', 'size': 1},
#   {'name': 'corona virus disease 2019 severe pneumonia -', 'size': 2},
#   {'name': 'cutaneous complaints', 'size': 1},
#   {'name': 'ground op', 'size': 113},
#   {'name': 'infection with', 'size': 79},
#   {'name': 'left ventricular dysfunction', 'size': 31},
#   {'name': 'lower respiratory tract infection', 'size': 30},
#   {'name': 'multi - organ disease', 'size': 8},
#   {'name': 'myocardial injury', 'size': 469},
#   {'name': 'noncommunicable chronic diseases', 'size': 2},
#   {'name': 'novel covirus disease', 'size': 9},
#   {'name': 'op', 'size': 355},
#   {'name': 'oxygen lung injury', 'size': 2},
#   {'name': 'polyneuropathy', 'size': 19},
#   {'name': 'post - tonsillectomy hemorrhage', 'size': 2},
#   {'name': 'proximal femoral fracture', 'size': 5},
#   {'name': 'pseudo perniosis', 'size': 2},
#   {'name': 'related Coronavirus 2', 'size': 1},
#   {'name': 'seizures', 'size': 283},
#   {'name': 'COVID 19 disease', 'size': 6},
#   {'name': 'Hypoemia', 'size': 8},
#   {'name': 'Hypopmia', 'size': 1},
#   {'name': 'IMID', 'size': 27},
#   {'name': 'SARA - CoV - 2', 'size': 12},
#   {'name': 'SARS - CoV - 2 virusvirus', 'size': 4},
#   {'name': 'Severe acute respiratory syndrome', 'size': 843},
#   {'name': 'Severe acute respiratory syndrome coronavirus 2 (', 'size': 5},
#   {'name': 'actinic keratosis', 'size': 2},
#   {'name': 'acute diabetic ketoacidosis', 'size': 3},
#   {'name': 'aspergillosis', 'size': 54},
#   {'name': 'blurred vision', 'size': 12},
#   {'name': 'bone marrow dysfunction', 'size': 3},
#   {'name': 'can', 'size': 98},
#   {'name': 'cerebrovascular disease', 'size': 170},
#   {'name': 'cerebrovascular diseases', 'size': 40},
#   {'name': 'chemosensory dysfunction', 'size': 15},
#   {'name': 'chest pressure', 'size': 2},
#   {'name': 'covirus 2019 disease', 'size': 16},
#   {'name': 'dyslipidaemia', 'size': 21},
#   {'name': 'head and neck on', 'size': 14},
#   {'name': 'hy', 'size': 302},
#   {'name': 'skin', 'size': 27},
#   {'name': 'swine', 'size': 107},
#   {'name': 'unconlled hyperglycemia', 'size': 7},
#   {'name': 'vascular disease', 'size': 26},
#   {'name': 'ALI', 'size': 208},
#   {'name': 'Co Vus 2019', 'size': 3},
#   {'name': 'Coronavirus infectious diseases', 'size': 2},
#   {'name': 'Dysphon', 'size': 1},
#   {'name': 'Introduction Coronavirus Disease', 'size': 1},
#   {'name': 'Liver Disease', 'size': 6},
#   {'name': 'M . tuberculosis', 'size': 12},
#   {'name': 'Novel coronavirus disease', 'size': 86},
#   {'name': 'acute cerebrovascular events', 'size': 8},
#   {'name': 'anovel coronavirus virus disease', 'size': 1},
#   {'name': 'covirus - 19 disease', 'size': 4},
#   {'name': 'covirus 2019', 'size': 446},
#   {'name': 'deficiencies in the natriuretic peptide hormone system',
#    'size': 2},
#   {'name': 'felin', 'size': 33},
#   {'name': 'hcymia', 'size': 1},
#   {'name': 'hematologic malignancies', 'size': 33},
#   {'name': 'micro d', 'size': 1},
#   {'name': 'myocial ischemia', 'size': 2},
#   {'name': 'ne on', 'size': 2},
#   {'name': 'non - COVID - related diseases', 'size': 1},
#   {'name': 'portal inflammation', 'size': 6},
#   {'name': 'prediabetes', 'size': 6},
#   {'name': 'severe / critical illness', 'size': 1},
#   {'name': 'shoulder pain', 'size': 8},
#   {'name': 'stress cardiomyopathy', 'size': 24},
#   {'name': 'thbos', 'size': 21},
#   {'name': 'Coronavirus disease COVID - 19', 'size': 6},
#   {'name': 'GHD', 'size': 9},
#   {'name': 'LF', 'size': 16},
#   {'name': 'Sudden anosmia', 'size': 2},
#   {'name': 'acalculous cholecystitis', 'size': 3},
#   {'name': 'acute coronary syndromes', 'size': 43},
#   {'name': 'ageusiacancer', 'size': 2},
#   {'name': 'arrhyth', 'size': 37},
#   {'name': 'bat SARS - likeV', 'size': 1},
#   {'name': 'cardio - cerebrovascular disease', 'size': 12},
#   {'name': 'cardiovascular and cancer disease', 'size': 2},
#   {'name': 'common cold - like illness', 'size': 1},
#   {'name': 'coronavirus - 2019', 'size': 4},
#   {'name': 'demic coronavirus disease 2019', 'size': 1},
#   {'name': 'gas', 'size': 17},
#   {'name': 'gtal warts', 'size': 4},
#   {'name': 'haostasis abnormalities', 'size': 3},
#   {'name': 'hne activation', 'size': 2},
#   {'name': 'incontinence', 'size': 2},
#   {'name': 'limb paralysis', 'size': 3},
#   {'name': 'loss of smell', 'size': 123},
#   {'name': 'malignant tumor', 'size': 18},
#   {'name': 'neuropsychiatric and neurodegenerative diseases', 'size': 4},
#   {'name': 'oral conditions', 'size': 5},
#   {'name': 'oy disorder', 'size': 3},
#   {'name': 'pleuritic chest pain', 'size': 13},
#   {'name': 'pulmonary infection', 'size': 78},
#   ...],
#  'links': [{'source': 2656, 'target': 0},
#   {'source': 2656, 'target': 1},
#   {'source': 2656, 'target': 2},
#   {'source': 2656, 'target': 10},
#   {'source': 2656, 'target': 12},
#   {'source': 2656, 'target': 13},
#   {'source': 2656, 'target': 16},
#   {'source': 2656, 'target': 21},
#   {'source': 2656, 'target': 25},
#   {'source': 2656, 'target': 27},
#   {'source': 2656, 'target': 28},
#   {'source': 2656, 'target': 29},
#   {'source': 2656, 'target': 30},
#   {'source': 2656, 'target': 31},
#   {'source': 2656, 'target': 33},
#   {'source': 2656, 'target': 34},
#   {'source': 2656, 'target': 36},
#   {'source': 2656, 'target': 40},
#   {'source': 2656, 'target': 41},
#   {'source': 2656, 'target': 43},
#   {'source': 2656, 'target': 45},
#   {'source': 2656, 'target': 46},
#   {'source': 2656, 'target': 48},
#   {'source': 2656, 'target': 50},
#   {'source': 2656, 'target': 54},
#   {'source': 2656, 'target': 55},
#   {'source': 2656, 'target': 56},
#   {'source': 2656, 'target': 59},
#   {'source': 2656, 'target': 60},
#   {'source': 2656, 'target': 61},
#   {'source': 2656, 'target': 62},
#   {'source': 2656, 'target': 63},
#   {'source': 2656, 'target': 65},
#   {'source': 2656, 'target': 67},
#   {'source': 2656, 'target': 70},
#   {'source': 2656, 'target': 71},
#   {'source': 2656, 'target': 72},
#   {'source': 2656, 'target': 73},
#   {'source': 2656, 'target': 74},
#   {'source': 2656, 'target': 76},
#   {'source': 2656, 'target': 77},
#   {'source': 2656, 'target': 78},
#   {'source': 2656, 'target': 79},
#   {'source': 2656, 'target': 81},
#   {'source': 2656, 'target': 84},
#   {'source': 2656, 'target': 86},
#   {'source': 2656, 'target': 91},
#   {'source': 2656, 'target': 92},
#   {'source': 2656, 'target': 93},
#   {'source': 2656, 'target': 96},
#   {'source': 2656, 'target': 97},
#   {'source': 2656, 'target': 98},
#   {'source': 2656, 'target': 99},
#   {'source': 2656, 'target': 100},
#   {'source': 2656, 'target': 101},
#   {'source': 2656, 'target': 102},
# ...
#   {'source': 2656, 'target': 1202},
#   {'source': 2656, 'target': 1203},
#   {'source': 2656, 'target': 1205},
#   {'source': 2656, 'target': 1206},
#   {'source': 2656, 'target': 1210},
#   {'source': 2656, 'target': 1211},
#   {'source': 2656, 'target': 1212},
#   {'source': 2656, 'target': 1213},
#   {'source': 2656, 'target': 1219},
#   {'source': 2656, 'target': 1220},
#   {'source': 2656, 'target': 1221},
#   {'source': 2656, 'target': 1226},
#   {'source': 2656, 'target': 1228},
#   {'source': 2656, 'target': 1229},
#   {'source': 2656, 'target': 1233},
#   {'source': 2656, 'target': 1235},
#   {'source': 2656, 'target': 1236},
#   {'source': 2656, 'target': 1243},
#   {'source': 2656, 'target': 1244},
#   {'source': 2656, 'target': 1245},
#   {'source': 2656, 'target': 1247},
#   {'source': 2656, 'target': 1249},
#   {'source': 2656, 'target': 1250},
#   {'source': 2656, 'target': 1251},
#   {'source': 2656, 'target': 1252},
#   {'source': 2656, 'target': 1254},
#   {'source': 2656, 'target': 1256},
#   {'source': 2656, 'target': 1260},
#   {'source': 2656, 'target': 1264},
#   {'source': 2656, 'target': 1266},
#   {'source': 2656, 'target': 1267},
#   {'source': 2656, 'target': 1269},
#   {'source': 2656, 'target': 1271},
#   {'source': 2656, 'target': 1272},
#   {'source': 2656, 'target': 1273},
#   {'source': 2656, 'target': 1275},
#   {'source': 2656, 'target': 1279},
#   {'source': 2656, 'target': 1284},
#   {'source': 2656, 'target': 1285},
#   {'source': 2656, 'target': 1288},
#   {'source': 2656, 'target': 1293},
#   {'source': 2656, 'target': 1295},
#   {'source': 2656, 'target': 1300},
#   {'source': 2656, 'target': 1301},
#   {'source': 2656, 'target': 1303},
#   {'source': 2656, 'target': 1307},
#   {'source': 2656, 'target': 1309},
#   {'source': 2656, 'target': 1310},
#   {'source': 2656, 'target': 1311},
#   {'source': 2656, 'target': 1313},
#   {'source': 2656, 'target': 1314},
#   {'source': 2656, 'target': 1317},
#   {'source': 2656, 'target': 1320},
#   {'source': 2656, 'target': 1328},
#   {'source': 2656, 'target': 1331},
#   {'source': 2656, 'target': 1332},
#   {'source': 2656, 'target': 1333},
#   {'source': 2656, 'target': 1334},
#   {'source': 2656, 'target': 1335},
#   {'source': 2656, 'target': 1343},
#   {'source': 2656, 'target': 1349},
#   {'source': 2656, 'target': 1353},
#   {'source': 2656, 'target': 1354},
#   {'source': 2656, 'target': 1355},
#   {'source': 2656, 'target': 1356},
#   {'source': 2656, 'target': 1357},
#   {'source': 2656, 'target': 1358},
#   {'source': 2656, 'target': 1360},
#   {'source': 2656, 'target': 1362},
#   {'source': 2656, 'target': 1365},
#   {'source': 2656, 'target': 1370},
#   {'source': 2656, 'target': 1373},
#   {'source': 2656, 'target': 1375},
#   {'source': 2656, 'target': 1378},
#   {'source': 2656, 'target': 1380},
#   {'source': 2656, 'target': 1381},
#   {'source': 2656, 'target': 1383},
#   {'source': 2656, 'target': 1387},
#   {'source': 2656, 'target': 1388},
#   {'source': 2656, 'target': 1393},
#   {'source': 2656, 'target': 1397},
#   {'source': 2656, 'target': 1398},
#   {'source': 2656, 'target': 1400},
#   {'source': 2656, 'target': 1401},
#   {'source': 2656, 'target': 1402},
#   {'source': 2656, 'target': 1405},
#   {'source': 2656, 'target': 1407},
#   {'source': 2656, 'target': 1409},
#   {'source': 2656, 'target': 1411},
#   {'source': 2656, 'target': 1414},
#   {'source': 2656, 'target': 1415},
#   {'source': 2656, 'target': 1416},
#   {'source': 2656, 'target': 1417},
#   {'source': 2656, 'target': 1418},
#   {'source': 2656, 'target': 1420},
#   {'source': 2656, 'target': 1424},
#   {'source': 2656, 'target': 1426},
#   {'source': 2656, 'target': 1430},
#   {'source': 2656, 'target': 1432},
#   {'source': 2656, 'target': 1433},
#   {'source': 2656, 'target': 1435},
#   {'source': 2656, 'target': 1440},
#   {'source': 2656, 'target': 1442},
#   {'source': 2656, 'target': 1448},
#   {'source': 2656, 'target': 1449},
#   {'source': 2656, 'target': 1452},
#   {'source': 2656, 'target': 1453},
#   {'source': 2656, 'target': 1454},
#   {'source': 2656, 'target': 1455},
#   {'source': 2656, 'target': 1457},
#   {'source': 2656, 'target': 1462},
#   {'source': 2656, 'target': 1463},
#   {'source': 2656, 'target': 1465},
#   {'source': 2656, 'target': 1466},
#   {'source': 2656, 'target': 1467},
#   {'source': 2656, 'target': 1468},
#   {'source': 2656, 'target': 1469},
#   {'source': 2656, 'target': 1475},
#   {'source': 2656, 'target': 1476},
#   {'source': 2656, 'target': 1477},
#   {'source': 2656, 'target': 1480},
#   {'source': 2656, 'target': 1482},
#   {'source': 2656, 'target': 1484},
#   {'source': 2656, 'target': 1485},
#   {'source': 2656, 'target': 1486},
#   {'source': 2656, 'target': 1490},
#   {'source': 2656, 'target': 1491},
#   {'source': 2656, 'target': 1494},
#   {'source': 2656, 'target': 1496},
#   {'source': 2656, 'target': 1499},
#   {'source': 2656, 'target': 1501},
#   {'source': 2656, 'target': 1506},
#   {'source': 2656, 'target': 1508},
#   {'source': 2656, 'target': 1509},
#   {'source': 2656, 'target': 1511},
#   {'source': 2656, 'target': 1517},
#   {'source': 2656, 'target': 1522},
#   {'source': 2656, 'target': 1523},
#   {'source': 2656, 'target': 1525},
#   {'source': 2656, 'target': 1528},
#   {'source': 2656, 'target': 1529},
#   {'source': 2656, 'target': 1530},
#   {'source': 2656, 'target': 1531},
#   {'source': 2656, 'target': 1536},
#   {'source': 2656, 'target': 1537},
#   {'source': 2656, 'target': 1539},
#   {'source': 2656, 'target': 1542},
#   {'source': 2656, 'target': 1546},
#   {'source': 2656, 'target': 1547},
#   {'source': 2656, 'target': 1549},
#   {'source': 2656, 'target': 1550},
#   {'source': 2656, 'target': 1552},
#   {'source': 2656, 'target': 1556},
#   {'source': 2656, 'target': 1557},
#   {'source': 2656, 'target': 1559},
#   {'source': 2656, 'target': 1560},
#   {'source': 2656, 'target': 1562},
#   {'source': 2656, 'target': 1565},
#   {'source': 2656, 'target': 1568},
#   {'source': 2656, 'target': 1569},
#   {'source': 2656, 'target': 1570},
#   {'source': 2656, 'target': 1571},
#   {'source': 2656, 'target': 1572},
#   {'source': 2656, 'target': 1575},
#   {'source': 2656, 'target': 1577},
#   {'source': 2656, 'target': 1578},
#   {'source': 2656, 'target': 1586},
#   {'source': 2656, 'target': 1589},
#   {'source': 2656, 'target': 1590},
#   {'source': 2656, 'target': 1591},
#   {'source': 2656, 'target': 1592},
#   {'source': 2656, 'target': 1595},
#   {'source': 2656, 'target': 1600},
#   {'source': 2656, 'target': 1606},
#   {'source': 2656, 'target': 1608},
#   {'source': 2656, 'target': 1616},
#   {'source': 2656, 'target': 1617},
#   {'source': 2656, 'target': 1618},
#   {'source': 2656, 'target': 1619},
#   {'source': 2656, 'target': 1623},
#   {'source': 2656, 'target': 1624},
#   {'source': 2656, 'target': 1625},
#   {'source': 2656, 'target': 1627},
#   {'source': 2656, 'target': 1628},
#   {'source': 2656, 'target': 1633},
#   {'source': 2656, 'target': 1637},
#   {'source': 2656, 'target': 1643},
#   {'source': 2656, 'target': 1644},
#   {'source': 2656, 'target': 1652},
#   {'source': 2656, 'target': 1654},
#   {'source': 2656, 'target': 1657},
#   {'source': 2656, 'target': 1659},
#   {'source': 2656, 'target': 1661},
#   {'source': 2656, 'target': 1662},
#   {'source': 2656, 'target': 1663},
#   {'source': 2656, 'target': 1664},
#   {'source': 2656, 'target': 1665},
#   {'source': 2656, 'target': 1666},
#   {'source': 2656, 'target': 1667},
#   {'source': 2656, 'target': 1668},
#   {'source': 2656, 'target': 1670},
#   {'source': 2656, 'target': 1673},
#   {'source': 2656, 'target': 1675},
#   {'source': 2656, 'target': 1678},
#   {'source': 2656, 'target': 1681},
#   {'source': 2656, 'target': 1682},
#   {'source': 2656, 'target': 1683},
#   {'source': 2656, 'target': 1684},
#   {'source': 2656, 'target': 1687},
#   {'source': 2656, 'target': 1689},
#   {'source': 2656, 'target': 1690},
#   {'source': 2656, 'target': 1694},
#   {'source': 2656, 'target': 1698},
#   {'source': 2656, 'target': 1699},
#   {'source': 2656, 'target': 1703},
#   {'source': 2656, 'target': 1704},
#   {'source': 2656, 'target': 1707},
#   {'source': 2656, 'target': 1708},
#   {'source': 2656, 'target': 1709},
#   {'source': 2656, 'target': 1710},
#   {'source': 2656, 'target': 1715},
#   {'source': 2656, 'target': 1716},
#   {'source': 2656, 'target': 1718},
#   {'source': 2656, 'target': 1724},
#   {'source': 2656, 'target': 1727},
#   {'source': 2656, 'target': 1728},
#   {'source': 2656, 'target': 1729},
#   {'source': 2656, 'target': 1731},
#   {'source': 2656, 'target': 1732},
#   {'source': 2656, 'target': 1735},
#   {'source': 2656, 'target': 1736},
#   {'source': 2656, 'target': 1737},
#   {'source': 2656, 'target': 1738},
#   {'source': 2656, 'target': 1742},
#   {'source': 2656, 'target': 1743},
#   {'source': 2656, 'target': 1744},
#   {'source': 2656, 'target': 1745},
#   {'source': 2656, 'target': 1746},
#   {'source': 2656, 'target': 1749},
#   {'source': 2656, 'target': 1750},
#   {'source': 2656, 'target': 1754},
#   {'source': 2656, 'target': 1762},
#   {'source': 2656, 'target': 1764},
#   {'source': 2656, 'target': 1767},
#   {'source': 2656, 'target': 1768},
#   {'source': 2656, 'target': 1771},
#   {'source': 2656, 'target': 1772},
#   {'source': 2656, 'target': 1774},
#   {'source': 2656, 'target': 1777},
#   {'source': 2656, 'target': 1782},
#   {'source': 2656, 'target': 1783},
#   {'source': 2656, 'target': 1784},
#   {'source': 2656, 'target': 1787},
#   {'source': 2656, 'target': 1791},
#   {'source': 2656, 'target': 1796},
#   {'source': 2656, 'target': 1798},
#   {'source': 2656, 'target': 1799},
#   {'source': 2656, 'target': 1801},
#   {'source': 2656, 'target': 1803},
#   {'source': 2656, 'target': 1804},
#   {'source': 2656, 'target': 1805},
#   {'source': 2656, 'target': 1806},
#   {'source': 2656, 'target': 1807},
#   {'source': 2656, 'target': 1808},
#   {'source': 2656, 'target': 1813},
#   {'source': 2656, 'target': 1814},
#   {'source': 2656, 'target': 1815},
#   {'source': 2656, 'target': 1816},
#   {'source': 2656, 'target': 1817},
#   {'source': 2656, 'target': 1818},
#   {'source': 2656, 'target': 1820},
#   {'source': 2656, 'target': 1821},
#   {'source': 2656, 'target': 1822},
#   {'source': 2656, 'target': 1823},
#   {'source': 2656, 'target': 1836},
#   {'source': 2656, 'target': 1837},
#   {'source': 2656, 'target': 1838},
#   {'source': 2656, 'target': 1840},
#   {'source': 2656, 'target': 1841},
#   {'source': 2656, 'target': 1843},
#   {'source': 2656, 'target': 1846},
#   {'source': 2656, 'target': 1847},
#   {'source': 2656, 'target': 1848},
#   {'source': 2656, 'target': 1850},
#   {'source': 2656, 'target': 1852},
#   {'source': 2656, 'target': 1858},
#   {'source': 2656, 'target': 1859},
#   {'source': 2656, 'target': 1860},
#   {'source': 2656, 'target': 1862},
#   {'source': 2656, 'target': 1863},
#   {'source': 2656, 'target': 1864},
#   {'source': 2656, 'target': 1865},
#   {'source': 2656, 'target': 1866},
#   {'source': 2656, 'target': 1867},
#   {'source': 2656, 'target': 1868},
#   {'source': 2656, 'target': 1869},
#   {'source': 2656, 'target': 1870},
#   {'source': 2656, 'target': 1872},
#   {'source': 2656, 'target': 1873},
#   {'source': 2656, 'target': 1876},
#   {'source': 2656, 'target': 1877},
#   {'source': 2656, 'target': 1879},
#   {'source': 2656, 'target': 1880},
#   {'source': 2656, 'target': 1882},
#   {'source': 2656, 'target': 1883},
#   {'source': 2656, 'target': 1889},
#   {'source': 2656, 'target': 1895},
#   {'source': 2656, 'target': 1896},
#   {'source': 2656, 'target': 1897},
#   {'source': 2656, 'target': 1898},
#   {'source': 2656, 'target': 1899},
#   {'source': 2656, 'target': 1900},
#   {'source': 2656, 'target': 1901},
#   {'source': 2656, 'target': 1903},
#   {'source': 2656, 'target': 1904},
#   {'source': 2656, 'target': 1908},
#   {'source': 2656, 'target': 1909},
#   {'source': 2656, 'target': 1910},
#   {'source': 2656, 'target': 1911},
#   {'source': 2656, 'target': 1917},
#   {'source': 2656, 'target': 1918},
#   {'source': 2656, 'target': 1920},
#   {'source': 2656, 'target': 1924},
#   {'source': 2656, 'target': 1931},
#   {'source': 2656, 'target': 1932},
#   {'source': 2656, 'target': 1935},
#   {'source': 2656, 'target': 1936},
#   {'source': 2656, 'target': 1941},
#   {'source': 2656, 'target': 1942},
#   {'source': 2656, 'target': 1945},
#   {'source': 2656, 'target': 1946},
#   {'source': 2656, 'target': 1950},
#   {'source': 2656, 'target': 1954},
#   {'source': 2656, 'target': 1955},
#   {'source': 2656, 'target': 1957},
#   {'source': 2656, 'target': 1958},
#   {'source': 2656, 'target': 1959},
#   {'source': 2656, 'target': 1963},
#   {'source': 2656, 'target': 1964},
#   {'source': 2656, 'target': 1965},
#   {'source': 2656, 'target': 1967},
#   {'source': 2656, 'target': 1972},
#   {'source': 2656, 'target': 1974},
#   {'source': 2656, 'target': 1977},
#   {'source': 2656, 'target': 1979},
#   {'source': 2656, 'target': 1983},
#   {'source': 2656, 'target': 1988},
#   {'source': 2656, 'target': 1991},
#   {'source': 2656, 'target': 1992},
#   {'source': 2656, 'target': 1996},
#   {'source': 2656, 'target': 1997},
#   {'source': 2656, 'target': 2001},
#   {'source': 2656, 'target': 2002},
#   {'source': 2656, 'target': 2004},
#   {'source': 2656, 'target': 2006},
#   {'source': 2656, 'target': 2012},
#   {'source': 2656, 'target': 2013},
#   {'source': 2656, 'target': 2016},
#   {'source': 2656, 'target': 2018},
#   {'source': 2656, 'target': 2020},
#   {'source': 2656, 'target': 2021},
#   {'source': 2656, 'target': 2022},
#   {'source': 2656, 'target': 2023},
#   {'source': 2656, 'target': 2024},
#   {'source': 2656, 'target': 2026},
#   {'source': 2656, 'target': 2027},
#   {'source': 2656, 'target': 2028},
#   {'source': 2656, 'target': 2031},
#   {'source': 2656, 'target': 2035},
#   {'source': 2656, 'target': 2037},
#   {'source': 2656, 'target': 2039},
#   {'source': 2656, 'target': 2041},
#   {'source': 2656, 'target': 2042},
#   {'source': 2656, 'target': 2043},
#   {'source': 2656, 'target': 2044},
#   {'source': 2656, 'target': 2045},
#   {'source': 2656, 'target': 2046},
#   {'source': 2656, 'target': 2047},
#   {'source': 2656, 'target': 2048},
#   {'source': 2656, 'target': 2050},
#   {'source': 2656, 'target': 2051},
#   {'source': 2656, 'target': 2052},
#   {'source': 2656, 'target': 2055},
#   {'source': 2656, 'target': 2057},
#   {'source': 2656, 'target': 2058},
#   {'source': 2656, 'target': 2060},
#   {'source': 2656, 'target': 2062},
#   {'source': 2656, 'target': 2063},
#   {'source': 2656, 'target': 2068},
#   {'source': 2656, 'target': 2073},
#   {'source': 2656, 'target': 2074},
#   {'source': 2656, 'target': 2075},
#   {'source': 2656, 'target': 2077},
#   {'source': 2656, 'target': 2079},
#   {'source': 2656, 'target': 2083},
#   {'source': 2656, 'target': 2084},
#   {'source': 2656, 'target': 2085},
#   {'source': 2656, 'target': 2086},
#   {'source': 2656, 'target': 2087},
#   {'source': 2656, 'target': 2090},
#   {'source': 2656, 'target': 2092},
#   {'source': 2656, 'target': 2096},
#   {'source': 2656, 'target': 2097},
#   {'source': 2656, 'target': 2098},
#   {'source': 2656, 'target': 2101},
#   {'source': 2656, 'target': 2105},
#   {'source': 2656, 'target': 2106},
#   {'source': 2656, 'target': 2111},
#   {'source': 2656, 'target': 2112},
#   {'source': 2656, 'target': 2116},
#   {'source': 2656, 'target': 2117},
#   {'source': 2656, 'target': 2118},
#   {'source': 2656, 'target': 2119},
#   {'source': 2656, 'target': 2122},
#   {'source': 2656, 'target': 2125},
#   {'source': 2656, 'target': 2129},
#   {'source': 2656, 'target': 2130},
#   {'source': 2656, 'target': 2131},
#   {'source': 2656, 'target': 2132},
#   {'source': 2656, 'target': 2133},
#   {'source': 2656, 'target': 2134},
#   {'source': 2656, 'target': 2135},
#   {'source': 2656, 'target': 2136},
#   {'source': 2656, 'target': 2142},
#   {'source': 2656, 'target': 2145},
#   {'source': 2656, 'target': 2146},
#   {'source': 2656, 'target': 2149},
#   {'source': 2656, 'target': 2150},
#   {'source': 2656, 'target': 2151},
#   {'source': 2656, 'target': 2157},
#   {'source': 2656, 'target': 2161},
#   {'source': 2656, 'target': 2164},
#   {'source': 2656, 'target': 2167},
#   {'source': 2656, 'target': 2170},
#   {'source': 2656, 'target': 2172},
#   {'source': 2656, 'target': 2176},
#   {'source': 2656, 'target': 2183},
#   {'source': 2656, 'target': 2186},
#   {'source': 2656, 'target': 2187},
#   {'source': 2656, 'target': 2188},
#   {'source': 2656, 'target': 2189},
#   {'source': 2656, 'target': 2190},
#   {'source': 2656, 'target': 2194},
#   {'source': 2656, 'target': 2196},
#   ...]}

# %%
import json
with open('graph.json', 'w') as f:
    json.dump(graph, f, indent=4,)

# %%
# %%html
# <div id="d3-example"></div>
# <style>
# .node {stroke: #fff; stroke-width: 1.5px;}
# .link {stroke: #999; stroke-opacity: .9;}
# </style>

# %%
# %%javascript
# // We load the d3.js library from the Web.
# require.config({paths:
#     {d3: "http://d3js.org/d3.v3.min"}});
# require(["d3"], function(d3) {
#   // The code in this block is executed when the
#   // d3.js library has been loaded.
#
#   // First, we specify the size of the canvas
#   // containing the visualization (size of the
#   // <div> element).
#   var width = 900, height = 600;
#
#   // We create a color scale.
#   var color = d3.scale.category10();
#
#   // We create a force-directed dynamic graph layout.
#   var force = d3.layout.force()
#     .charge(-120)
#     .linkDistance(30)
#     .size([width, height]);
#
#   // In the <div> element, we create a <svg> graphic
#   // that will contain our interactive visualization.
#   var svg = d3.select("#d3-example").select("svg")
#   if (svg.empty()) {
#     svg = d3.select("#d3-example").append("svg")
#           .attr("width", width)
#           .attr("height", height);
#   }
#
#   // We load the JSON file.
#   d3.json("graph.json", function(error, graph) {
#     // In this block, the file has been loaded
#     // and the 'graph' object contains our graph.
#
#     // We load the nodes and links in the
#     // force-directed graph.
#     force.nodes(graph.nodes)
#       .links(graph.links)
#       .start();
#
#     // We create a <line> SVG element for each link
#     // in the graph.
#     var link = svg.selectAll(".link")
#       .data(graph.links)
#       .enter().append("line")
#       .attr("class", "link");
#
#     // We create a <circle> SVG element for each node
#     // in the graph, and we specify a few attributes.
#     var node = svg.selectAll(".node")
#       .data(graph.nodes)
#       .enter().append("circle")
#       .attr("class", "node")
#       .attr("r", 5)  // radius
#       .style("fill", function(d) {
#          // The node color depends on the club.
#          return color(d.size);
#       })
#       .call(force.drag);
#
#     // The name of each node is the node number.
#     node.append("title")
#         .text(function(d) { return d.name; });
#
#     // We bind the positions of the SVG elements
#     // to the positions of the dynamic force-directed
#     // graph, at each time step.
#     force.on("tick", function() {
#       link.attr("x1", function(d){return d.source.x})
#           .attr("y1", function(d){return d.source.y})
#           .attr("x2", function(d){return d.target.x})
#           .attr("y2", function(d){return d.target.y});
#
#       node.attr("cx", function(d){return d.x})
#           .attr("cy", function(d){return d.y});
#     });
#   });
# });

# %%
import networkx as nx
gp = nx.from_pandas_edgelist(g.edges.where(col("dst")=="1").toPandas(),'src','dst')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6));
nx.draw_networkx(gp, ax=ax)

# %%
import json
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g = nx.karate_club_graph()

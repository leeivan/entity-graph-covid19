# %%
from pyspark.sql import SparkSession
from pyspark.sql.functions import lit
from functools import reduce
from pyspark.sql import DataFrame

# %%
spark = SparkSession.builder.getOrCreate()

# %%
dfs_sections = spark.read \
.format("jdbc") \
.option("url", "jdbc:sqlite:/nfs/workspaces/datasets/covid-19/articles.sqlite") \
.option("dbtable", "(SELECT * FROM sections)").load()
dfs_sections.show()
dfs_articles = spark.read \
.format("jdbc") \
.option("url", "jdbc:sqlite:/nfs/workspaces/datasets/covid-19/articles.sqlite") \
.option("query", "(SELECT * FROM articles)") \
.option("customSchema", "Published STRING, Entry STRING").load()
dfs_articles.show()
dfs_citations = spark.read \
.format("jdbc") \
.option("url", "jdbc:sqlite:/nfs/workspaces/datasets/covid-19/articles.sqlite") \
.option("query", "(SELECT * FROM citations)").load()
dfs_citations.show()
# Out:
# +---+--------+--------+------+-----+--------------------+-----------+
# | Id| Article|    Tags|Design| Name|                Text|     Labels|
# +---+--------+--------+------+-----+--------------------+-----------+
# |  0|wvx6q999|COVID-19|     0|TITLE|Note from the edi...|   FRAGMENT|
# |  1|wvx6q999|COVID-19|     0| null|The situation has...|       null|
# |  2|wvx6q999|COVID-19|     0| null|Meanwhile, on 7 J...|       null|
# |  3|wvx6q999|COVID-19|     0| null|In order to suppo...|       null|
# |  4|wvx6q999|COVID-19|     0| null|For example, ther...|   FRAGMENT|
# |  5|wvx6q999|COVID-19|     0| null|In this issue of ...|   FRAGMENT|
# |  6|wvx6q999|COVID-19|     0| null|One is a research...|   FRAGMENT|
# |  7|wvx6q999|COVID-19|     0| null|on the developmen...|       null|
# |  8|wvx6q999|COVID-19|     0| null|Before this publi...|       null|
# |  9|wvx6q999|COVID-19|     0| null|The other is a ra...|       null|
# | 10|wvx6q999|COVID-19|     0| null|It also points ou...|   FRAGMENT|
# | 11|wvx6q999|COVID-19|     0| null|Today, the WHO Di...|   FRAGMENT|
# | 12|wvx6q999|COVID-19|     0| null|International hea...|       null|
# | 13|wvx6q999|COVID-19|     0| null|ECDC has set up a...|       null|
# | 14|wvx6q999|COVID-19|     0| null|At the end of 201...|       null|
# | 15|wvx6q999|COVID-19|     0| null|Just a day earlie...|       null|
# | 16|wvx6q999|COVID-19|     0| null|The post indicate...|SAMPLE_SIZE|
# | 17|wvx6q999|COVID-19|     0| null|In their accompan...|       null|
# | 18|wvx6q999|COVID-19|     0| null|severe acute resp...|   FRAGMENT|
# | 19|wvx6q999|COVID-19|     0| null|In order to suppo...|       null|
# +---+--------+--------+------+-----+--------------------+-----------+
# only showing top 20 rows
#
# +--------+------+-------------------+--------------------+--------------------+--------------------+--------+------+----+--------------------+--------------------+--------------------+----------+
# |      Id|Source|          Published|         Publication|             Authors|               Title|    Tags|Design|Size|              Sample|              Method|           Reference|     Entry|
# +--------+------+-------------------+--------------------+--------------------+--------------------+--------+------+----+--------------------+--------------------+--------------------+----------+
# |wvx6q999|   PMC|2020-01-23 00:00:00|       Euro Surveill|                null|Note from the edi...|COVID-19|     0|  20|The post indicate...|                null|https://www.ncbi....|2020-03-27|
# |64q3qcjy|   PMC|2020-02-27 00:00:00|       Euro Surveill|                null|Latest assessment...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-03-27|
# |bd7whqxf|   PMC|2020-03-05 00:00:00|       Euro Surveill|                null|Updated rapid ris...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-03-27|
# |l3ijkmwy|   PMC|2020-03-12 00:00:00|       Euro Surveill|                null|Updated rapid ris...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-03-27|
# |54glvasa|   PMC|2020-03-12 00:00:00|Med Klin Intensiv...|Kluge, Stefan; Ja...|Empfehlungen zur ...|COVID-19|     0|null|Grundsätzlich emp...|                null|https://www.ncbi....|2020-05-19|
# |t4ro1rl9|   PMC|2020-03-18 00:00:00|  Intensive Care Med|Corradi, F.; Via,...|Lung ultrasound a...|COVID-19|     0|null|The potential adv...|Semiquantitative ...|https://www.ncbi....|2020-05-19|
# |88hibsk5|   PMC|2020-03-23 00:00:00|Bone Marrow Trans...|Szer, Jeff; Weisd...|The impact of COV...|COVID-19|     0|null|The database cont...|The database cont...|https://www.ncbi....|2020-05-19|
# |8k34ed1o|   PMC|2020-03-30 00:00:00|    MMW Fortschr Med|                null|Fortbildung in Ze...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-04-03|
# |7s2i3sbj|   PMC|2020-03-30 00:00:00|    MMW Fortschr Med|                null|Schon junge Ärzte...|COVID-19|     0|null|COVID-19 spielte ...|COVID-19 spielte ...|https://www.ncbi....|2020-04-03|
# |1ob719sh|   PMC|2020-03-27 00:00:00|           Br Dent J|      Sellars, Shaun|   Interesting times|COVID-19|     0|null|Costs for alterna...|As 2020 enters fu...|https://www.ncbi....|2020-04-03|
# |cgcuzxdt|   PMC|2020-03-04 00:00:00|               Orbis| Shattuck, Thomas J.|The Race to Zero?...|COVID-19|     0|   2|The two men had p...|Between her elect...|https://www.ncbi....|2020-05-12|
# |apcueljv|   PMC|2020-03-19 00:00:00|   Lancet Psychiatry|Zhai, Yusen; Du, Xue|Mental health car...|COVID-19|     0|null|Coronavirus disea...|Coronavirus disea...|https://www.ncbi....|2020-06-04|
# |13pj0wmb|   PMC|2020-03-20 00:00:00|Lancet Public Health|Armitage, Richard...|COVID-19 and the ...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-03-27|
# |umz2v0ka|   PMC|2020-03-30 00:00:00|       Health Expect|      Aslani, Parisa|What are our heal...|COVID-19|     0|null|For weeks, we wer...|For weeks, we wer...|https://www.ncbi....|2020-04-10|
# |wuuhlowd|   PMC|2020-04-01 00:00:00|          Inter Econ|     Valkonen, Tarmo|The Finnish Pensi...|COVID-19|     9|null|Several new early...|Private sector pe...|https://www.ncbi....|2020-05-19|
# |1mchg5yg|   PMC|2020-03-09 00:00:00|                null|Zhao, Shi; Cao, P...|COVID-19 and gend...|COVID-19|     0|   8|1 The mechanism b...|We examined the p...|https://www.ncbi....|2020-04-10|
# |6dwpkjaj|   PMC|2020-03-26 00:00:00|       Euro Surveill|                null|Updated rapid ris...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-04-10|
# |qwc0inzi|   PMC|2020-03-11 00:00:00|       J Nurse Pract| Neal-Boylan, Leslie|Are We Ready for ...|COVID-19|     0|   4|I quickly moved m...|                null|https://www.ncbi....|2020-05-19|
# |cmqtarm0|   PMC|2020-03-30 00:00:00|        Lancet Oncol| The Lancet Oncology|COVID-19: global ...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-04-03|
# |vahd59z8|   PMC|2020-04-01 00:00:00|  J Am Med Dir Assoc|Cesari, Matteo; P...|COVID-19 in Italy...|COVID-19|     0|null|                null|                null|https://www.ncbi....|2020-05-19|
# +--------+------+-------------------+--------------------+--------------------+--------------------+--------+------+----+--------------------+--------------------+--------------------+----------+
# only showing top 20 rows
#
# +--------------------+--------+
# |               Title|Mentions|
# +--------------------+--------+
# |                null|   25717|
# |Detection of 2019...|     878|
# |Real-time tentati...|       6|
# |Risk assessment: ...|       4|
# |European Centre f...|      37|
# |Real-time tentati...|      82|
# |Novel 2019 corona...|       5|
# |Undiagnosed pneum...|       1|
# |Laboratory testin...|      18|
# |Detection of 2019...|      43|
# |Covid-19 drug int...|       4|
# |Clinicalcourseand...|       5|
# |Clinical features...|    3607|
# |AWMF (2020) S3-Le...|       1|
# |Exhaled air dispe...|      57|
# |Novel coronavirus...|       5|
# |Staff safety duri...|      95|
# |AWMF (2017) S3-Le...|       2|
# |Novel coronavirus...|      12|
# |COVID-19: a novel...|      35|
# +--------------------+--------+
# only showing top 20 rows

# %%
ner_type = ["BC2GM","BC4CHEMD","BC5CDR-chem","BC5CDR-disease","JNLPBA","NCBI-disease","linnaeus","s800"]
ner_app = []
for item in ner_type :
    ner_path = "/nfs/storages/bio_corpus/ner/"+ item  + "/all_entity.csv"
    df = spark.read.format("csv").option("header","true").load(ner_path)
    df = df.withColumn("type", lit(item))
    ner_app.append(df)
df_ner_all = reduce(DataFrame.unionAll, ner_app)
df_ner_all = df_ner_all.withColumnRenamed("type", "ner_type")
df_ner_all.show()
# Out:
# +--------------------+---+----------+--------+
# |              entity|  n|section_id|ner_type|
# +--------------------+---+----------+--------+
# |                AAK1|  1|      1522|   BC2GM|
# |      Januase Kinase|  1|      1523|   BC2GM|
# |              IL - 8|  1|      3461|   BC2GM|
# |              IL - 8|  2|      3461|   BC2GM|
# |              IL - 8|  3|      3461|   BC2GM|
# |                b A1|  1|      6798|   BC2GM|
# |                BafA|  2|      6798|   BC2GM|
# |                BafA|  1|      6799|   BC2GM|
# |vacuolar type H (...|  2|      6799|   BC2GM|
# |          v - ATPase|  3|      6799|   BC2GM|
# |                   C|  1|      6800|   BC2GM|
# |                BafA|  2|      6800|   BC2GM|
# |mammalian target ...|  3|      6800|   BC2GM|
# |              mTORC1|  4|      6800|   BC2GM|
# |              mTORC1|  1|      6801|   BC2GM|
# |              mTORC1|  2|      6801|   BC2GM|
# |              mTORC1|  1|      6803|   BC2GM|
# |transcription fac...|  1|      6804|   BC2GM|
# |                TFEB|  2|      6804|   BC2GM|
# |              mTORC1|  3|      6804|   BC2GM|
# +--------------------+---+----------+--------+
# only showing top 20 rows

# %%
re_type = ["GAD","euadr"]
re_app = []
for item in re_type:
    re_path = "/nfs/storages/bio_corpus/re_all_in_one/" + item + "/all_relations.csv"
    df = spark.read.format("csv").option("header","true").load(re_path)
    df = df.withColumn("type", lit(item))
    re_app.append(df)

# %%
df_re_all = reduce(DataFrame.unionAll, re_app)
df_re_all = df_re_all.withColumnRenamed("type", "re_type")
df_re_all.show()
# Out:
# +----------+-------+
# |section_id|re_type|
# +----------+-------+
# |       222|    GAD|
# |      2780|    GAD|
# |      4270|    GAD|
# |      8822|    GAD|
# |      9142|    GAD|
# |      9614|    GAD|
# |      9998|    GAD|
# |     10000|    GAD|
# |     11154|    GAD|
# |     12708|    GAD|
# |     12709|    GAD|
# |     12710|    GAD|
# |     13385|    GAD|
# |     14966|    GAD|
# |     15913|    GAD|
# |     15918|    GAD|
# |     17060|    GAD|
# |     18664|    GAD|
# |     18665|    GAD|
# |     20429|    GAD|
# +----------+-------+
# only showing top 20 rows

# %%
df_ner_re = df_ner_all.join(df_re_all, "section_id")
df_ner_re.show()
df_ner_re_src = df_ner_re.withColumnRenamed("entity","entity_src") \
.withColumnRenamed("n", "n_src") \
.withColumnRenamed("ner_type", "ner_type_src") \
.withColumnRenamed("re_type", "re_type_src")
df_ner_re_src.show()
df_ner_re_dst = df_ner_re.withColumnRenamed("entity","entity_dst") \
.withColumnRenamed("n", "n_dst") \
.withColumnRenamed("ner_type", "ner_type_dst") \
.withColumnRenamed("re_type", "re_type_dst")
df_ner_re_dst.show()
df_ner_re_src_dst = df_ner_re_src.join(df_ner_re_dst, "section_id")
df_ner_re_src_dst.show()
df_ner_re_src_dst = df_ner_re_src_dst.filter("entity_src != entity_dst") \
.filter("re_type_src == re_type_dst") \
.filter("ner_type_src == ner_type_dst")
# Out:
# +----------+--------------------+---+--------+-------+
# |section_id|              entity|  n|ner_type|re_type|
# +----------+--------------------+---+--------+-------+
# |      1523|      Januase Kinase|  1|   BC2GM|  euadr|
# |      6799|                BafA|  1|   BC2GM|  euadr|
# |      6799|vacuolar type H (...|  2|   BC2GM|  euadr|
# |      6799|          v - ATPase|  3|   BC2GM|  euadr|
# |      6803|              mTORC1|  1|   BC2GM|  euadr|
# |      6805|                BafA|  1|   BC2GM|  euadr|
# |      6805|              mTORC1|  2|   BC2GM|  euadr|
# |     10479|                   h|  1|   BC2GM|  euadr|
# |     16293|   ribosome helicase|  1|   BC2GM|  euadr|
# |     18261|                  CR|  1|   BC2GM|  euadr|
# |     18261|              Cas13b|  2|   BC2GM|  euadr|
# |     18265|              Cas13b|  1|   BC2GM|  euadr|
# |     20120|      HLA - B27 mRNA|  1|   BC2GM|  euadr|
# |     20122|      HLA - B27 mRNA|  1|   BC2GM|  euadr|
# |     23056|               renin|  1|   BC2GM|  euadr|
# |     23056|         angiotensin|  2|   BC2GM|  euadr|
# |     23056|                  RA|  3|   BC2GM|  euadr|
# |     23058| Angiotensin peptide|  1|   BC2GM|  euadr|
# |     23059|               renin|  1|   BC2GM|  euadr|
# |     23059|         angiotensin|  2|   BC2GM|  euadr|
# +----------+--------------------+---+--------+-------+
# only showing top 20 rows
#
# +----------+--------------------+-----+------------+-----------+
# |section_id|          entity_src|n_src|ner_type_src|re_type_src|
# +----------+--------------------+-----+------------+-----------+
# |      1523|      Januase Kinase|    1|       BC2GM|      euadr|
# |      6799|                BafA|    1|       BC2GM|      euadr|
# |      6799|vacuolar type H (...|    2|       BC2GM|      euadr|
# |      6799|          v - ATPase|    3|       BC2GM|      euadr|
# |      6803|              mTORC1|    1|       BC2GM|      euadr|
# |      6805|                BafA|    1|       BC2GM|      euadr|
# |      6805|              mTORC1|    2|       BC2GM|      euadr|
# |     10479|                   h|    1|       BC2GM|      euadr|
# |     16293|   ribosome helicase|    1|       BC2GM|      euadr|
# |     18261|                  CR|    1|       BC2GM|      euadr|
# |     18261|              Cas13b|    2|       BC2GM|      euadr|
# |     18265|              Cas13b|    1|       BC2GM|      euadr|
# |     20120|      HLA - B27 mRNA|    1|       BC2GM|      euadr|
# |     20122|      HLA - B27 mRNA|    1|       BC2GM|      euadr|
# |     23056|               renin|    1|       BC2GM|      euadr|
# |     23056|         angiotensin|    2|       BC2GM|      euadr|
# |     23056|                  RA|    3|       BC2GM|      euadr|
# |     23058| Angiotensin peptide|    1|       BC2GM|      euadr|
# |     23059|               renin|    1|       BC2GM|      euadr|
# |     23059|         angiotensin|    2|       BC2GM|      euadr|
# +----------+--------------------+-----+------------+-----------+
# only showing top 20 rows
#
# +----------+--------------------+-----+------------+-----------+
# |section_id|          entity_dst|n_dst|ner_type_dst|re_type_dst|
# +----------+--------------------+-----+------------+-----------+
# |      1523|      Januase Kinase|    1|       BC2GM|      euadr|
# |      6799|                BafA|    1|       BC2GM|      euadr|
# |      6799|vacuolar type H (...|    2|       BC2GM|      euadr|
# |      6799|          v - ATPase|    3|       BC2GM|      euadr|
# |      6803|              mTORC1|    1|       BC2GM|      euadr|
# |      6805|                BafA|    1|       BC2GM|      euadr|
# |      6805|              mTORC1|    2|       BC2GM|      euadr|
# |     10479|                   h|    1|       BC2GM|      euadr|
# |     16293|   ribosome helicase|    1|       BC2GM|      euadr|
# |     18261|                  CR|    1|       BC2GM|      euadr|
# |     18261|              Cas13b|    2|       BC2GM|      euadr|
# |     18265|              Cas13b|    1|       BC2GM|      euadr|
# |     20120|      HLA - B27 mRNA|    1|       BC2GM|      euadr|
# |     20122|      HLA - B27 mRNA|    1|       BC2GM|      euadr|
# |     23056|               renin|    1|       BC2GM|      euadr|
# |     23056|         angiotensin|    2|       BC2GM|      euadr|
# |     23056|                  RA|    3|       BC2GM|      euadr|
# |     23058| Angiotensin peptide|    1|       BC2GM|      euadr|
# |     23059|               renin|    1|       BC2GM|      euadr|
# |     23059|         angiotensin|    2|       BC2GM|      euadr|
# +----------+--------------------+-----+------------+-----------+
# only showing top 20 rows
#
# +----------+----------+-----+--------------+-----------+-----------+-----+--------------+-----------+
# |section_id|entity_src|n_src|  ner_type_src|re_type_src| entity_dst|n_dst|  ner_type_dst|re_type_dst|
# +----------+----------+-----+--------------+-----------+-----------+-----+--------------+-----------+
# |   1000888|        CO|    1|BC5CDR-disease|      euadr| COVID - 19|    1|  NCBI-disease|      euadr|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr| COVID - 19|    1|  NCBI-disease|        GAD|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr|respiratory|    2|  NCBI-disease|      euadr|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr|respiratory|    2|  NCBI-disease|        GAD|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr| COVID - 19|    3|  NCBI-disease|      euadr|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr| COVID - 19|    3|  NCBI-disease|        GAD|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr| COVID - 19|    1|          s800|      euadr|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr| COVID - 19|    1|          s800|        GAD|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr|   COD - 19|    2|          s800|      euadr|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr|   COD - 19|    2|          s800|        GAD|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr|    patient|    1|      linnaeus|      euadr|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr|    patient|    1|      linnaeus|        GAD|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr|         CO|    1|BC5CDR-disease|      euadr|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr|         CO|    1|BC5CDR-disease|        GAD|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr|respiratory|    2|BC5CDR-disease|      euadr|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr|respiratory|    2|BC5CDR-disease|        GAD|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr|         CO|    3|BC5CDR-disease|      euadr|
# |   1000888|        CO|    1|BC5CDR-disease|      euadr|         CO|    3|BC5CDR-disease|        GAD|
# |   1000888|        CO|    1|BC5CDR-disease|        GAD| COVID - 19|    1|  NCBI-disease|      euadr|
# |   1000888|        CO|    1|BC5CDR-disease|        GAD| COVID - 19|    1|  NCBI-disease|        GAD|
# +----------+----------+-----+--------------+-----------+-----------+-----+--------------+-----------+
# only showing top 20 rows

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import *

# %%
e_drop_duplicate = df_ner_re_src_dst.withColumn("entity_pair",array_join(array_sort(array(col("entity_src"),col("entity_dst"))),"_")).dropDuplicates(["entity_pair"]).drop("entity_pair")

# %%
from pyspark.sql.window import Window as W
v = df_ner_all.groupBy("entity").agg(collect_set("section_id").alias("sections"))

# %%
v.cache()
# Out:
# DataFrame[entity: string, sections: array<string>]

# %%
v = v.withColumn("idx", monotonically_increasing_id())
windowSpec = W.orderBy("idx")
v = v.withColumn("id", row_number().over(windowSpec)).drop("idx")
v.show()
# Out:
# +--------------------+--------------------+---+
# |              entity|            sections| id|
# +--------------------+--------------------+---+
# |"Taxifolin 3 ' - ...|           [1278739]|  1|
# |$ \ beta $ - hairpin|           [1539578]|  2|
# |         ( E , E ) -|           [1503298]|  3|
# |- 19 and H1N1 swi...|  [5220609, 1411652]|  4|
# |              - Nrf2|           [6906166]|  5|
# |        - nCV N gene|           [3823453]|  6|
# |         - occlusion|   [1123441, 642104]|  7|
# |- related infections|   [1354288, 665292]|  8|
# |1 , 2 , 3 , 4 - t...|[1291599, 8620851...|  9|
# |1 , 3 , 6 - trihy...|           [1538143]| 10|
# |       1 microglobul|           [6290762]| 11|
# |                 13C|[874533, 1470080,...| 12|
# |     17β - estradiol|           [3906171]| 13|
# |     1ab polyprotein|[622787, 920614, ...| 14|
# |2 , 2 ' - Azino -...|            [853792]| 15|
# |2019 - nCoV main ...|[682594, 7808126,...| 16|
# |2019 Corona Virus...|[7274121, 1352238...| 17|
# |3 , 5 - Di - O - ...|  [1064612, 3040722]| 18|
# |3 - to - 5 exonuc...|           [5398839]| 19|
# |     3CL pro complex|  [5569142, 1583834]| 20|
# +--------------------+--------------------+---+
# only showing top 20 rows

# %%
v.filter("entity = 'COVID - 19'").show()
# Out:
# +----------+--------------------+-----+
# |    entity|            sections|   id|
# +----------+--------------------+-----+
# |COVID - 19|[6430795, 1018353...|45423|
# +----------+--------------------+-----+

# %%
e_drop_duplicate = e_drop_duplicate.select("entity_src","entity_dst","re_type_src")
# e = e.withColumnRenamed("entity_src", "src").withColumnRenamed("entity_dst", "dst") \
# .withColumnRenamed("re_type_src", "relationship")
e_drop_duplicate.show()
# Out:
# +--------------------+--------------------+-----------+
# |          entity_src|          entity_dst|re_type_src|
# +--------------------+--------------------+-----------+
# |sesquiterpen hydr...|( E ) - ß - farne...|      euadr|
# |                   ,|   Alloyohimbine , ,|      euadr|
# |                 3CL|           - ACE - 2|      euadr|
# |  palindrome repeats|               - Cas|      euadr|
# |             - LARP1|        5 ′ TOP mRNA|        GAD|
# |                coki|            / IL - 6|        GAD|
# |1 , 10 - phenanth...|[ Co ( indo - O ,...|      euadr|
# |                 111|               human|      euadr|
# |14 - 3 - 3 protei...|               YWHAE|      euadr|
# |       spike protein|2 - O - ribose me...|        GAD|
# |                trip|             2 ′ - C|      euadr|
# |         2019 - nCoV|      angiotensin II|      euadr|
# |receptor binding ...|        2019 - spike|      euadr|
# |      SARS - CoV - 2|            2019 nCO|      euadr|
# |             24 , 25|                   e|      euadr|
# |             Aularin|3 , 5 - Di - O - ...|      euadr|
# |                ACE2|          3CLpro ‐ 1|      euadr|
# |      5p - replicase|           orf1 / ab|      euadr|
# |7 Pangolin - Cov ...|                ORFs|      euadr|
# |        stem - loops|       A - site tRNA|      euadr|
# +--------------------+--------------------+-----------+
# only showing top 20 rows

# %%
e_drop_duplicate = e_drop_duplicate.join(v, e_drop_duplicate.entity_src == v.entity).select("id","entity_dst","re_type_src").withColumnRenamed("id","src")
e = e_drop_duplicate.join(v, e_drop_duplicate.entity_dst == v.entity).select("id","src","re_type_src").withColumnRenamed("id","dst").withColumnRenamed("re_type_src","relationship")

# %%
e.cache()
# Out:
# DataFrame[dst: int, src: int, relationship: string]

# %%
e.show()
# Out:
# +---+-----+------------+
# |dst|  src|relationship|
# +---+-----+------------+
# |  1|26113|       euadr|
# |  1|50272|       euadr|
# |  1|77094|       euadr|
# |  1|34433|       euadr|
# |  5|53014|       euadr|
# |  9|18661|         GAD|
# | 10|50656|       euadr|
# | 13|28406|       euadr|
# | 13|95216|       euadr|
# | 18|48101|       euadr|
# | 18| 4370|       euadr|
# | 18|26521|       euadr|
# | 18|93377|       euadr|
# | 19|17642|       euadr|
# | 19|33829|         GAD|
# | 19|91314|         GAD|
# | 19|47794|         GAD|
# | 19|70152|         GAD|
# | 19|93139|         GAD|
# | 19|32219|       euadr|
# +---+-----+------------+
# only showing top 20 rows

# %%
from graphframes import *
g = GraphFrame(v,e)

# %%
gad_g = g.filterVertices("entity like '%COVID%'").dropIsolatedVertices()

# %%
gad_g = g.filterEdges("src = 45423 or dst = 45423").dropIsolatedVertices()

# %%
gad_g.vertices.count()
# Out:
# 283

# %%
gad_g.edges.count()
# Out:
# 382

# %%
gad_g_v = gad_g.vertices.select("id").rdd.flatMap(lambda x: x).collect()

# %%
nodes = [{'name': i["entity"], 'size': i["size"]}
         for i in gad_g.vertices.select("entity", size("sections").alias("size")).collect()]

# %%
links = [{'source': gad_g_v.index(u["source"]), 'target': gad_g_v.index(u["target"])}
         for u in gad_g.edges.withColumnRenamed("dst","target").withColumnRenamed("src","source").select("source","target","relationship").collect()]

# %%
graph = {'nodes': nodes, "links": links}

# %%
graph
# Out:
# {'nodes': [{'name': 'COVID - 19 distress', 'size': 8},
#   {'name': 'COVID - op', 'size': 1},
#   {'name': 'severe COVID - 19', 'size': 12},
#   {'name': 'COVID - 19D - 19', 'size': 37},
#   {'name': 'COVID - 19VI - 19', 'size': 6},
#   {'name': 'COVID - 19 A', 'size': 3},
#   {'name': 'SARS - CoV - 2 and COVID - 19', 'size': 3},
#   {'name': 'COVID - 19 infections', 'size': 584},
#   {'name': 'Coronavirus COVID - 19', 'size': 10},
#   {'name': 'severe and critical COVID - 19', 'size': 2},
#   {'name': 'COVID - 19 anti', 'size': 5},
#   {'name': 'COVID ) of', 'size': 2},
#   {'name': 'COVID - 19 pneumonia', 'size': 2415},
#   {'name': 'COVID - 19 health', 'size': 12},
#   {'name': 'COVID of', 'size': 4},
#   {'name': 'COVID related pneumonia', 'size': 2},
#   {'name': 'COVID - 19 associated pulmonary aspergillosis', 'size': 2},
#   {'name': 'COVID - 19 hypoxemia', 'size': 1},
#   {'name': 'COVID ‐ 9', 'size': 1},
#   {'name': 'COVID19 virus', 'size': 5},
#   {'name': 'COD - 19 CT CX COVID - 19 CXR', 'size': 2},
#   {'name': 'novel coronavirus ( COVID - 19 ) disease', 'size': 4},
#   {'name': 'COVID - 19 virus', 'size': 508},
#   {'name': 'COVID19 disease', 'size': 12},
#   {'name': 'COVID - 19 infectious diseases', 'size': 2},
#   {'name': 'COVID - 19 syndrome Coronavirus 2', 'size': 1},
#   {'name': 'COVID - 19 - SE', 'size': 2},
#   {'name': 'COVID ’ s - 19', 'size': 1},
#   {'name': 'coronavirus disease 2019 ( COVID - 19 )', 'size': 9},
#   {'name': 'COVID - 19 vasculopathy', 'size': 2},
#   {'name': 'COVID COVID -', 'size': 1},
#   {'name': 'COVID infection', 'size': 62},
#   {'name': 'COVID ‐ 19 viral infection', 'size': 2},
#   {'name': 'COVID ‐ 19 disease', 'size': 90},
#   {'name': 'COVID - 19 anosmia', 'size': 8},
#   {'name': 'COVIDVI', 'size': 19},
#   {'name': 'COVID ‐ 19 related', 'size': 5},
#   {'name': 'COVID - 19 cough', 'size': 8},
#   {'name': 'COVID ‐ 19 chilblains', 'size': 2},
#   {'name': 'COVID ‐ 19 and', 'size': 1},
#   {'name': 'non - COVID viral pneumonia', 'size': 6},
#   {'name': 'COVID - 19 im', 'size': 2},
#   {'name': 'COVID - 19 lung infection', 'size': 5},
#   {'name': 'COVID - 19 coagulopathy', 'size': 20},
#   {'name': 'COVID 19 disease', 'size': 6},
#   {'name': 'COVIDheumatic', 'size': 2},
#   {'name': 'non - COVID - related diseases', 'size': 1},
#   {'name': 'COVID -ph', 'size': 1},
#   {'name': 'Coronavirus disease COVID - 19', 'size': 6},
#   {'name': 'COVID - 19 - related', 'size': 92},
#   {'name': 'COVID 19 virus', 'size': 13},
#   {'name': 'COVID -D', 'size': 8},
#   {'name': 'COVID - infected', 'size': 2},
#   {'name': 'COVID ‐ 19 pneumonia', 'size': 93},
#   {'name': 'COVID ‐ related', 'size': 1},
#   {'name': 'COVID - 19 lung infections', 'size': 7},
#   {'name': 'COVID - 19VID - 19', 'size': 37},
#   {'name': 'COVID - infections', 'size': 2},
#   {'name': 'COVID - 19 viruses', 'size': 9},
#   {'name': 'COVID - 2019', 'size': 230},
#   {'name': 'COVID ‐ 19 ‐ related kidney disease', 'size': 1},
#   {'name': 'COVID - 19 )', 'size': 65},
#   {'name': 'COVID - 19 Grave - Coronavirus 2', 'size': 1},
#   {'name': 'COVID - 19 genome sequences', 'size': 1},
#   {'name': 'COVID - 19 19', 'size': 35},
#   {'name': 'COVID - 19 d', 'size': 18},
#   {'name': 'COVID - 19 CXR', 'size': 2},
#   {'name': 'COVID - 19 infectionuria', 'size': 1},
#   {'name': 'COVID - 19 and clavicle', 'size': 1},
#   {'name': 'COVID - 19 disease', 'size': 1737},
#   {'name': 'COVID - 19 pneumonitis', 'size': 34},
#   {'name': 'vere COVID - 19', 'size': 3},
#   {'name': 'COVID - 19 co', 'size': 43},
#   {'name': 'COVID 19D', 'size': 1},
#   {'name': 'COVID19 infection', 'size': 51},
#   {'name': 'neurological disorders COVID - 19', 'size': 2},
#   {'name': 'COVID - 19 associated pneumonia', 'size': 38},
#   {'name': 'COVID disease', 'size': 51},
#   {'name': 'COVID - 19 irritation', 'size': 2},
#   {'name': 'non - COVID related illness', 'size': 3},
#   {'name': 'COVID - 19 ) Coronavirus disease', 'size': 1},
#   {'name': 'COVID - 19 chilblains', 'size': 7},
#   {'name': 'COVID -VID', 'size': 12},
#   {'name': 'COVID ‐ 19 related co', 'size': 1},
#   {'name': 'human COVID - 19', 'size': 39},
#   {'name': 'COVID - 19 pulmonary infection', 'size': 4},
#   {'name': 'COVID - 19VI', 'size': 30},
#   {'name': 'COVID - 19 - n', 'size': 1},
#   {'name': 'COVID - 19 neurologic symptoms', 'size': 1},
#   {'name': 'COVID pneumonia', 'size': 27},
#   {'name': 'COVID - 19 , coronavirus disease', 'size': 2},
#   {'name': 'COVID - 19virus', 'size': 51},
#   {'name': 'COVID - 19 -', 'size': 100},
#   {'name': 'COVIDD', 'size': 11},
#   {'name': 'COVID ‐ 19 infection', 'size': 213},
#   {'name': 'COVID - 19 viral', 'size': 35},
#   {'name': 'COVID ‐ 19 infections', 'size': 17},
#   {'name': 'COVID - 19ious and Tropical', 'size': 1},
#   {'name': 'SARS - CoV - 2 COVID - 19', 'size': 31},
#   {'name': 'COVID - 19 damage', 'size': 5},
#   {'name': 'pande COVID', 'size': 1},
#   {'name': 'COVID - 19 pneumonia en', 'size': 4},
#   {'name': 'COVID - 19ronavirus', 'size': 3},
#   {'name': 'COVID - 19 - related kidney disease', 'size': 1},
#   {'name': 'COVID - 19 hemodialys hemodialys', 'size': 1},
#   {'name': 'COVID - 9', 'size': 14},
#   {'name': 'non - COVID - 19 severe respiratory viral infections', 'size': 2},
#   {'name': 'COVID - 19 gene sequences', 'size': 1},
#   {'name': 'COVID - 19T', 'size': 4},
#   {'name': 'Co COVID', 'size': 1},
#   {'name': 'COVID - 19 19 19', 'size': 2},
#   {'name': 'COVID - 19 hypoxia', 'size': 1},
#   {'name': 'COVID - 19 - associated', 'size': 47},
#   {'name': 'COVID - 19 respiratory syndrome', 'size': 4},
#   {'name': 'COVID - infection', 'size': 12},
#   {'name': 'COVID ‐ 19 viral', 'size': 3},
#   {'name': 'COVID - 19 syndrome', 'size': 43},
#   {'name': 'COVIDVID ground - glass opacity', 'size': 1},
#   {'name': 'COVID - UrolithiasD - 19', 'size': 1},
#   {'name': 'COVID - 19 - associated pulmonary aspergillosis', 'size': 6},
#   {'name': 'non - COVID - 19 respiratory disease', 'size': 1},
#   {'name': 'COVID - 19 illness', 'size': 186},
#   {'name': 'COVID - induced', 'size': 1},
#   {'name': 'COVID - 19VID -VID', 'size': 1},
#   {'name': 'COVID - 19 pneumonia COVID - 19 pneumonia', 'size': 11},
#   {'name': 'COVID - 19 ) virus', 'size': 18},
#   {'name': 'coronavirus ( COVID - 19', 'size': 20},
#   {'name': 'coronavirus ( COVID - 19 fulminant myopericarditis', 'size': 1},
#   {'name': 'respiratory disease COVID - 19', 'size': 1},
#   {'name': 'COVID - 19 antibody', 'size': 31},
#   {'name': 'COVID - 19', 'size': 135604},
#   {'name': 'Coronavirus disease ( COVID - 19', 'size': 3},
#   {'name': 'COVID - 19 paraplegic', 'size': 2},
#   {'name': 'COVID - 19 related pneumonia', 'size': 15},
#   {'name': 'COVID - 19 tracheost', 'size': 1},
#   {'name': 'COVID - 19 COVID - 19', 'size': 8},
#   {'name': 'coronavirus disease 2019 ( COVID - 19 ) infection', 'size': 36},
#   {'name': 'novel coronavirus ( COVID - 19 ) infected pneumonia', 'size': 3},
#   {'name': 'COVID - 19 cardiac complications', 'size': 1},
#   {'name': 'COVID - 19V - 19', 'size': 2},
#   {'name': 'COVID - 19 infectious disease', 'size': 14},
#   {'name': 'COVID - 19 pneumonia con opities', 'size': 2},
#   {'name': 'COVID - 19 pneumopathy', 'size': 4},
#   {'name': 'nCOVID - 19', 'size': 29},
#   {'name': 'COVID - 19 complications', 'size': 60},
#   {'name': 'COVID - 19int', 'size': 15},
#   {'name': 'COVID - 19 conditions', 'size': 10},
#   {'name': 'COVID - 19 infected', 'size': 55},
#   {'name': 'COVID - 9 infection', 'size': 2},
#   {'name': 'COVID necrotizing leukoencephalopathy', 'size': 2},
#   {'name': 'COVID - 19 related', 'size': 67},
#   {'name': 'COVID - 19a', 'size': 2},
#   {'name': 'COVID - related', 'size': 1},
#   {'name': '[UNK] COVID', 'size': 1},
#   {'name': 'COVID - 19 infected pneumonia', 'size': 4},
#   {'name': 'COVID heart', 'size': 3},
#   {'name': 'COVID - 19Q', 'size': 3},
#   {'name': 'COVID - 19hr', 'size': 3},
#   {'name': 'COVID - 19 genomes', 'size': 1},
#   {'name': 'non - COVID - 19 related medical conditions', 'size': 1},
#   {'name': 'non - COVID - 19 viral pneumonia', 'size': 1},
#   {'name': 'COVID -', 'size': 2608},
#   {'name': 'COVID - 19 ) pneumonia', 'size': 37},
#   {'name': 'COVID - 19 - associated pneumonia', 'size': 30},
#   {'name': 'COVID - 19 pandemia', 'size': 10},
#   {'name': 'COVID19 _ GIST _ HSA', 'size': 3},
#   {'name': 'COVID - 19 related rash', 'size': 1},
#   {'name': 'SA COVID - 19', 'size': 1},
#   {'name': 'COVID - 19 - related death', 'size': 14},
#   {'name': 'COVID - 19 pulmonary injury', 'size': 2},
#   {'name': 'COVID - 19VID 19', 'size': 14},
#   {'name': 'COVID co', 'size': 3},
#   {'name': 'COVID - 19 com', 'size': 1},
#   {'name': 'COVID - 19D -', 'size': 3},
#   {'name': 'COVID - 19 ( + )', 'size': 3},
#   {'name': 'COVID - 19virus 2019', 'size': 2},
#   {'name': 'COVID infections', 'size': 4},
#   {'name': 'COVID - 19 - related diabetes', 'size': 2},
#   {'name': 'COVID - 19 function', 'size': 3},
#   {'name': 'COVID - carotid atherothrombosis', 'size': 2},
#   {'name': 'COVID - 19 ) disease', 'size': 12},
#   {'name': 'COVID into', 'size': 1},
#   {'name': 'COVID - 19 condition', 'size': 11},
#   {'name': 'COVID - 19 critical illness', 'size': 17},
#   {'name': 'COVID - 19 hyper', 'size': 4},
#   {'name': 'COVID - 19 organizing pneumonia', 'size': 2},
#   {'name': 'COVID - 19VID - 19VID - 19', 'size': 4},
#   {'name': 'COVID - 19troint nelogicaliovascular', 'size': 1},
#   {'name': 'COVID19 lung lesions', 'size': 1},
#   {'name': 'COVID - 19 c release syndrome', 'size': 2},
#   {'name': 'coronavirus disease ( COVID - 19 ) pneumonia', 'size': 16},
#   {'name': 'COVID - 19 - related deaths', 'size': 5},
#   {'name': 'COVID - 19 and', 'size': 30},
#   {'name': 'COVID - Net', 'size': 1},
#   {'name': 'COVID - 19 illnessVID 19', 'size': 1},
#   {'name': 'COVID 19', 'size': 6248},
#   {'name': 'COVIDDVID', 'size': 2},
#   {'name': 'COVID - 19 an', 'size': 2},
#   {'name': 'COVID - 19 infection', 'size': 4241},
#   {'name': 'COVID - 19 myocarditis', 'size': 24},
#   {'name': 'COVID - 19 neurologic complications', 'size': 2},
#   {'name': 'COVID ‐ 19 associated fever', 'size': 1},
#   {'name': 'stage 1 / stage 2 COVID - 19 - related disease', 'size': 2},
#   {'name': 'COVID - 19 - associated disorders', 'size': 2},
#   {'name': 'coronavirus disease COVID - 19', 'size': 140},
#   {'name': 'COVID - 19 - related protein', 'size': 3},
#   {'name': 'COVIDpos', 'size': 4},
#   {'name': 'COVID - 19 - related lung disease', 'size': 1},
#   {'name': 'COVID - 19 covirus', 'size': 48},
#   {'name': 'COVID - 19 pulmonary symptoms', 'size': 2},
#   {'name': 'COVID - 19 related myocarditis', 'size': 3},
#   {'name': 'COVID 19 obes', 'size': 1},
#   {'name': 'COVID19 pneumonia', 'size': 12},
#   {'name': 'COVID - 19 ) Coronavirus', 'size': 1},
#   {'name': 'COVID - 19 morities', 'size': 2},
#   {'name': 'COVID - 19 ventilation', 'size': 3},
#   {'name': 'COVID - 2019 - HR2P1', 'size': 1},
#   {'name': '- COVID - 19 pulmonary disease', 'size': 2},
#   {'name': 'COVID - 19 viral infection', 'size': 10},
#   {'name': 'COVID - 19 abnormalities', 'size': 4},
#   {'name': 'COVID - 2019 - HR1P1', 'size': 2},
#   {'name': 'diabe COVID - 19', 'size': 2},
#   {'name': 'COVID - 19 diabetes obesity', 'size': 1},
#   {'name': 'COVID19', 'size': 747},
#   {'name': 'Coronavirus disease COVID', 'size': 2},
#   {'name': 'COVID - disease', 'size': 14},
#   {'name': 'COVIDVID', 'size': 49},
#   {'name': 'COVID - 19rhe', 'size': 2},
#   {'name': 'COVID - 19 Co', 'size': 4},
#   {'name': 'COVID - 19 associated co', 'size': 4},
#   {'name': 'COVID - 19 cutaneous reactions', 'size': 4},
#   {'name': 'COVID - 1912916 - 020 - 01551', 'size': 1},
#   {'name': 'COVID - 19 infection m', 'size': 1},
#   {'name': 'COVID - 19 - related illness', 'size': 10},
#   {'name': 'COVID ‐ 19', 'size': 4691},
#   {'name': 'COVID - 19 - 19', 'size': 65},
#   {'name': 'COVID - 19 pneumonia consolidation of', 'size': 1},
#   {'name': 'COVID damage', 'size': 1},
#   {'name': 'COVID ‐ 19 associated aspergillosis', 'size': 1},
#   {'name': 'COVID - 19 related encephalitis', 'size': 1},
#   {'name': 'COVID - 19 rheumatic', 'size': 2},
#   {'name': 'COVID - Induced Lymphocytosis', 'size': 1},
#   {'name': 'COVID 19VID', 'size': 13},
#   {'name': '[UNK] COVID 19', 'size': 1},
#   {'name': 'COVID - 19 dys', 'size': 3},
#   {'name': 'COVID - 19com', 'size': 5},
#   {'name': 'COVID - 2019 - HR2P2', 'size': 1},
#   {'name': 'COVID ‐', 'size': 273},
#   {'name': 'COVID - 19 M ( pro )', 'size': 1},
#   {'name': 'COVID - 19 associated', 'size': 51},
#   {'name': 'COVID ‐ 19 virus', 'size': 17},
#   {'name': 'COVID - 19 pneumoniaVIDVID - 19', 'size': 1},
#   {'name': 'COVID - 19VID', 'size': 68},
#   {'name': 'COVID - 19de', 'size': 13},
#   {'name': 'COVID ‐ 19 pneumonia exudative lesions', 'size': 1},
#   {'name': 'COVID - 19 c', 'size': 3},
#   {'name': 'COVID - 19 vision loss', 'size': 1},
#   {'name': 'COVID -VID -', 'size': 3},
#   {'name': 'COVID - 19 Vus', 'size': 2},
#   {'name': 'COVID 19 - related pneumonia', 'size': 3},
#   {'name': 'COVID conditions', 'size': 3},
#   {'name': 'COVIDS - 19 infection', 'size': 2},
#   {'name': 'COVID - 19 - related PTSD', 'size': 2},
#   {'name': 'COVID19T', 'size': 1},
#   {'name': 'COVID - 19 acute respiratory coronavirus 2', 'size': 1},
#   {'name': 'COVID toes', 'size': 8},
#   {'name': 'COVID - onset pneumoniavere Acute Respiratory Syndrome',
#    'size': 1},
#   {'name': 'COVID - 19 - S', 'size': 1},
#   {'name': 'COVID', 'size': 17408},
#   {'name': 'COVID - 19 ) infection', 'size': 105},
#   {'name': 'COVID - 19 related co', 'size': 1},
#   {'name': 'COVID - 19 - associated fever', 'size': 1},
#   {'name': 'COVID - 19 nose', 'size': 2},
#   {'name': 'COVID - 19 obes', 'size': 3},
#   {'name': 'COVIDpa', 'size': 1},
#   {'name': 'hyperinflammatory reaction to COVID -', 'size': 1},
#   {'name': 'COVID - 19 serum antibodies', 'size': 2},
#   {'name': 'non COVID - 19 pneumonia', 'size': 2},
#   {'name': 'COVID provoked thromboembolism', 'size': 3},
#   {'name': 'COVID - 19D', 'size': 33},
#   {'name': 'COVID - 19 - associated coagulopathy', 'size': 28},
#   {'name': 'COVID - 19 coughVID - 19 cough', 'size': 1},
#   {'name': 'COVID - 19VID -', 'size': 11}],
#  'links': [{'source': 130, 'target': 0},
#   {'source': 161, 'target': 0},
#   {'source': 130, 'target': 1},
#   {'source': 130, 'target': 2},
#   {'source': 252, 'target': 4},
#   {'source': 130, 'target': 4},
#   {'source': 12, 'target': 7},
#   {'source': 180, 'target': 7},
#   {'source': 195, 'target': 7},
#   {'source': 230, 'target': 7},
#   {'source': 130, 'target': 7},
#   {'source': 198, 'target': 7},
#   {'source': 116, 'target': 7},
#   {'source': 134, 'target': 7},
#   {'source': 61, 'target': 12},
#   {'source': 101, 'target': 12},
#   {'source': 130, 'target': 12},
#   {'source': 190, 'target': 12},
#   {'source': 198, 'target': 12},
#   {'source': 268, 'target': 12},
#   {'source': 195, 'target': 12},
#   {'source': 251, 'target': 12},
#   {'source': 161, 'target': 12},
#   {'source': 252, 'target': 13},
#   {'source': 76, 'target': 15},
#   {'source': 95, 'target': 22},
#   {'source': 125, 'target': 22},
#   {'source': 130, 'target': 22},
#   {'source': 130, 'target': 24},
#   {'source': 130, 'target': 27},
#   {'source': 130, 'target': 29},
#   {'source': 161, 'target': 30},
#   {'source': 198, 'target': 31},
#   {'source': 268, 'target': 31},
#   {'source': 268, 'target': 33},
#   {'source': 198, 'target': 34},
#   {'source': 195, 'target': 39},
#   {'source': 12, 'target': 40},
#   {'source': 130, 'target': 40},
#   {'source': 130, 'target': 42},
#   {'source': 229, 'target': 43},
#   {'source': 130, 'target': 44},
#   {'source': 130, 'target': 46},
#   {'source': 161, 'target': 47},
#   {'source': 130, 'target': 49},
#   {'source': 161, 'target': 49},
#   {'source': 234, 'target': 50},
#   {'source': 161, 'target': 51},
#   {'source': 234, 'target': 53},
#   {'source': 254, 'target': 53},
#   {'source': 234, 'target': 54},
#   {'source': 130, 'target': 55},
#   {'source': 12, 'target': 55},
#   {'source': 130, 'target': 56},
#   {'source': 156, 'target': 56},
#   {'source': 161, 'target': 59},
#   {'source': 234, 'target': 60},
#   {'source': 130, 'target': 65},
#   {'source': 268, 'target': 65},
#   {'source': 20, 'target': 66},
#   {'source': 198, 'target': 67},
#   {'source': 130, 'target': 68},
#   {'source': 31, 'target': 69},
#   {'source': 104, 'target': 69},
#   {'source': 146, 'target': 69},
#   {'source': 67, 'target': 69},
#   {'source': 278, 'target': 69},
#   {'source': 130, 'target': 70},
#   {'source': 2, 'target': 71},
#   {'source': 128, 'target': 71},
#   {'source': 130, 'target': 72},
#   {'source': 130, 'target': 73},
#   {'source': 268, 'target': 73},
#   {'source': 130, 'target': 74},
#   {'source': 223, 'target': 74},
#   {'source': 268, 'target': 77},
#   {'source': 230, 'target': 78},
#   {'source': 130, 'target': 79},
#   {'source': 161, 'target': 82},
#   {'source': 130, 'target': 82},
#   {'source': 268, 'target': 82},
#   {'source': 195, 'target': 83},
#   {'source': 195, 'target': 86},
#   {'source': 130, 'target': 88},
#   {'source': 130, 'target': 89},
#   {'source': 155, 'target': 89},
#   {'source': 77, 'target': 89},
#   {'source': 130, 'target': 91},
#   {'source': 26, 'target': 92},
#   {'source': 80, 'target': 92},
#   {'source': 234, 'target': 94},
#   {'source': 130, 'target': 95},
#   {'source': 234, 'target': 96},
#   {'source': 130, 'target': 97},
#   {'source': 130, 'target': 100},
#   {'source': 130, 'target': 103},
#   {'source': 8, 'target': 109},
#   {'source': 130, 'target': 109},
#   {'source': 121, 'target': 112},
#   {'source': 130, 'target': 113},
#   {'source': 268, 'target': 114},
#   {'source': 130, 'target': 116},
#   {'source': 268, 'target': 117},
#   {'source': 12, 'target': 119},
#   {'source': 12, 'target': 121},
#   {'source': 61, 'target': 121},
#   {'source': 12, 'target': 122},
#   {'source': 130, 'target': 123},
#   {'source': 130, 'target': 124},
#   {'source': 2, 'target': 128},
#   {'source': 10, 'target': 129},
#   {'source': 3, 'target': 130},
#   {'source': 8, 'target': 130},
#   {'source': 9, 'target': 130},
#   {'source': 105, 'target': 130},
#   {'source': 106, 'target': 130},
#   {'source': 114, 'target': 130},
#   {'source': 118, 'target': 130},
#   {'source': 145, 'target': 130},
#   {'source': 153, 'target': 130},
#   {'source': 170, 'target': 130},
#   {'source': 171, 'target': 130},
#   {'source': 175, 'target': 130},
#   {'source': 181, 'target': 130},
#   {'source': 99, 'target': 130},
#   {'source': 102, 'target': 130},
#   {'source': 186, 'target': 130},
#   {'source': 11, 'target': 130},
#   {'source': 121, 'target': 130},
#   {'source': 17, 'target': 130},
#   {'source': 208, 'target': 130},
#   {'source': 212, 'target': 130},
#   {'source': 131, 'target': 130},
#   {'source': 218, 'target': 130},
#   {'source': 139, 'target': 130},
#   {'source': 146, 'target': 130},
#   {'source': 226, 'target': 130},
#   {'source': 157, 'target': 130},
#   {'source': 41, 'target': 130},
#   {'source': 234, 'target': 130},
#   {'source': 240, 'target': 130},
#   {'source': 182, 'target': 130},
#   {'source': 183, 'target': 130},
#   {'source': 184, 'target': 130},
#   {'source': 5, 'target': 130},
#   {'source': 189, 'target': 130},
#   {'source': 58, 'target': 130},
#   {'source': 59, 'target': 130},
#   {'source': 13, 'target': 130},
#   {'source': 14, 'target': 130},
#   {'source': 251, 'target': 130},
#   {'source': 252, 'target': 130},
#   {'source': 199, 'target': 130},
#   {'source': 200, 'target': 130},
#   {'source': 21, 'target': 130},
#   {'source': 257, 'target': 130},
#   {'source': 75, 'target': 130},
#   {'source': 28, 'target': 130},
#   {'source': 262, 'target': 130},
#   {'source': 107, 'target': 130},
#   {'source': 217, 'target': 130},
#   {'source': 110, 'target': 130},
#   {'source': 111, 'target': 130},
#   {'source': 266, 'target': 130},
#   {'source': 272, 'target': 130},
#   {'source': 273, 'target': 130},
#   {'source': 120, 'target': 130},
#   {'source': 37, 'target': 130},
#   {'source': 87, 'target': 130},
#   {'source': 90, 'target': 130},
#   {'source': 125, 'target': 130},
#   {'source': 126, 'target': 130},
#   {'source': 127, 'target': 130},
#   {'source': 136, 'target': 130},
#   {'source': 48, 'target': 130},
#   {'source': 143, 'target': 130},
#   {'source': 51, 'target': 130},
#   {'source': 243, 'target': 130},
#   {'source': 162, 'target': 130},
#   {'source': 163, 'target': 130},
#   {'source': 164, 'target': 130},
#   {'source': 61, 'target': 130},
#   {'source': 63, 'target': 130},
#   {'source': 172, 'target': 130},
#   {'source': 177, 'target': 130},
#   {'source': 188, 'target': 130},
#   {'source': 192, 'target': 130},
#   {'source': 81, 'target': 130},
#   {'source': 84, 'target': 130},
#   {'source': 204, 'target': 130},
#   {'source': 268, 'target': 130},
#   {'source': 269, 'target': 130},
#   {'source': 206, 'target': 130},
#   {'source': 86, 'target': 130},
#   {'source': 25, 'target': 130},
#   {'source': 213, 'target': 130},
#   {'source': 222, 'target': 130},
#   {'source': 232, 'target': 130},
#   {'source': 235, 'target': 130},
#   {'source': 57, 'target': 130},
#   {'source': 64, 'target': 130},
#   {'source': 69, 'target': 130},
#   {'source': 85, 'target': 130},
#   {'source': 92, 'target': 130},
#   {'source': 278, 'target': 130},
#   {'source': 280, 'target': 130},
#   {'source': 98, 'target': 130},
#   {'source': 130, 'target': 132},
#   {'source': 130, 'target': 133},
#   {'source': 130, 'target': 135},
#   {'source': 130, 'target': 137},
#   {'source': 161, 'target': 137},
#   {'source': 144, 'target': 138},
#   {'source': 130, 'target': 140},
#   {'source': 173, 'target': 140},
#   {'source': 24, 'target': 140},
#   {'source': 12, 'target': 141},
#   {'source': 130, 'target': 142},
#   {'source': 130, 'target': 144},
#   {'source': 147, 'target': 144},
#   {'source': 130, 'target': 147},
#   {'source': 12, 'target': 147},
#   {'source': 268, 'target': 147},
#   {'source': 198, 'target': 148},
#   {'source': 130, 'target': 150},
#   {'source': 130, 'target': 151},
#   {'source': 130, 'target': 152},
#   {'source': 130, 'target': 154},
#   {'source': 130, 'target': 156},
#   {'source': 130, 'target': 158},
#   {'source': 130, 'target': 159},
#   {'source': 198, 'target': 159},
#   {'source': 130, 'target': 160},
#   {'source': 171, 'target': 161},
#   {'source': 130, 'target': 161},
#   {'source': 149, 'target': 161},
#   {'source': 252, 'target': 161},
#   {'source': 266, 'target': 161},
#   {'source': 65, 'target': 161},
#   {'source': 279, 'target': 161},
#   {'source': 268, 'target': 161},
#   {'source': 223, 'target': 161},
#   {'source': 57, 'target': 161},
#   {'source': 69, 'target': 161},
#   {'source': 195, 'target': 163},
#   {'source': 130, 'target': 166},
#   {'source': 130, 'target': 167},
#   {'source': 161, 'target': 168},
#   {'source': 130, 'target': 169},
#   {'source': 42, 'target': 169},
#   {'source': 130, 'target': 173},
#   {'source': 24, 'target': 173},
#   {'source': 130, 'target': 174},
#   {'source': 268, 'target': 176},
#   {'source': 130, 'target': 178},
#   {'source': 268, 'target': 179},
#   {'source': 161, 'target': 181},
#   {'source': 69, 'target': 181},
#   {'source': 130, 'target': 185},
#   {'source': 130, 'target': 187},
#   {'source': 130, 'target': 191},
#   {'source': 130, 'target': 193},
#   {'source': 12, 'target': 194},
#   {'source': 121, 'target': 194},
#   {'source': 61, 'target': 194},
#   {'source': 130, 'target': 195},
#   {'source': 198, 'target': 195},
#   {'source': 211, 'target': 195},
#   {'source': 62, 'target': 195},
#   {'source': 252, 'target': 195},
#   {'source': 268, 'target': 195},
#   {'source': 161, 'target': 195},
#   {'source': 223, 'target': 195},
#   {'source': 69, 'target': 195},
#   {'source': 226, 'target': 196},
#   {'source': 268, 'target': 196},
#   {'source': 130, 'target': 197},
#   {'source': 114, 'target': 198},
#   {'source': 202, 'target': 198},
#   {'source': 228, 'target': 198},
#   {'source': 241, 'target': 198},
#   {'source': 130, 'target': 198},
#   {'source': 136, 'target': 198},
#   {'source': 225, 'target': 198},
#   {'source': 161, 'target': 198},
#   {'source': 162, 'target': 198},
#   {'source': 261, 'target': 198},
#   {'source': 265, 'target': 198},
#   {'source': 269, 'target': 198},
#   {'source': 69, 'target': 198},
#   {'source': 234, 'target': 201},
#   {'source': 130, 'target': 203},
#   {'source': 165, 'target': 205},
#   {'source': 16, 'target': 207},
#   {'source': 130, 'target': 209},
#   {'source': 130, 'target': 210},
#   {'source': 12, 'target': 212},
#   {'source': 198, 'target': 214},
#   {'source': 130, 'target': 215},
#   {'source': 130, 'target': 219},
#   {'source': 246, 'target': 220},
#   {'source': 216, 'target': 220},
#   {'source': 268, 'target': 221},
#   {'source': 23, 'target': 223},
#   {'source': 19, 'target': 223},
#   {'source': 130, 'target': 223},
#   {'source': 131, 'target': 223},
#   {'source': 161, 'target': 226},
#   {'source': 130, 'target': 227},
#   {'source': 130, 'target': 228},
#   {'source': 130, 'target': 231},
#   {'source': 130, 'target': 233},
#   {'source': 32, 'target': 234},
#   {'source': 36, 'target': 234},
#   {'source': 195, 'target': 234},
#   {'source': 38, 'target': 234},
#   {'source': 268, 'target': 234},
#   {'source': 33, 'target': 234},
#   {'source': 130, 'target': 236},
#   {'source': 161, 'target': 237},
#   {'source': 53, 'target': 238},
#   {'source': 130, 'target': 239},
#   {'source': 130, 'target': 242},
#   {'source': 161, 'target': 242},
#   {'source': 130, 'target': 244},
#   {'source': 130, 'target': 245},
#   {'source': 216, 'target': 246},
#   {'source': 234, 'target': 247},
#   {'source': 130, 'target': 248},
#   {'source': 130, 'target': 249},
#   {'source': 115, 'target': 250},
#   {'source': 161, 'target': 251},
#   {'source': 130, 'target': 253},
#   {'source': 130, 'target': 255},
#   {'source': 130, 'target': 256},
#   {'source': 69, 'target': 256},
#   {'source': 130, 'target': 258},
#   {'source': 195, 'target': 259},
#   {'source': 268, 'target': 260},
#   {'source': 130, 'target': 261},
#   {'source': 223, 'target': 263},
#   {'source': 12, 'target': 264},
#   {'source': 130, 'target': 265},
#   {'source': 268, 'target': 265},
#   {'source': 130, 'target': 267},
#   {'source': 35, 'target': 268},
#   {'source': 7, 'target': 268},
#   {'source': 18, 'target': 268},
#   {'source': 226, 'target': 268},
#   {'source': 242, 'target': 268},
#   {'source': 52, 'target': 268},
#   {'source': 247, 'target': 268},
#   {'source': 252, 'target': 268},
#   {'source': 6, 'target': 268},
#   {'source': 87, 'target': 268},
#   {'source': 198, 'target': 268},
#   {'source': 51, 'target': 268},
#   {'source': 86, 'target': 268},
#   {'source': 223, 'target': 268},
#   {'source': 224, 'target': 268},
#   {'source': 45, 'target': 268},
#   {'source': 57, 'target': 268},
#   {'source': 72, 'target': 268},
#   {'source': 274, 'target': 268},
#   {'source': 89, 'target': 268},
#   {'source': 93, 'target': 268},
#   {'source': 282, 'target': 268},
#   {'source': 130, 'target': 270},
#   {'source': 130, 'target': 271},
#   {'source': 268, 'target': 275},
#   {'source': 108, 'target': 276},
#   {'source': 130, 'target': 277},
#   {'source': 195, 'target': 279},
#   {'source': 130, 'target': 279},
#   {'source': 268, 'target': 279},
#   {'source': 130, 'target': 281},
#   {'source': 198, 'target': 281},
#   {'source': 159, 'target': 281},
#   {'source': 130, 'target': 282},
#   {'source': 51, 'target': 282},
#   {'source': 269, 'target': 282},
#   {'source': 161, 'target': 282}]}

# %%
import json
with open('graph.json', 'w') as f:
    json.dump(graph, f, indent=4,)

# %%
import networkx as nx
gp = nx.from_pandas_edgelist(g.edges.where(col("dst")=="1").toPandas(),'src','dst')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig, ax = plt.subplots(1, 1, figsize=(8, 6));
nx.draw_networkx(gp, ax=ax)

# %%
import json
import numpy as np
import networkx as nx
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
g = nx.karate_club_graph()
